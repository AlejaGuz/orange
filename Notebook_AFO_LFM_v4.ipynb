# %% [markdown]
# # **Proyecto Orange**
# ### **Responsables: Andrés Felipe Ocampo, Alejandra Ruiz y Luis Felipe Montenegro**

# %% [markdown]
# # **Librerías**

# %%
# --- Librerías estándar ---
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# --- Estadística y pruebas ---
from scipy.stats import f_oneway, levene, shapiro, pearsonr, kruskal, spearmanr, kendalltau
import scipy.stats as stats  # para otras funciones estadísticas

# --- Modelos y regresión ---
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OrdinalEncoder

# --- Statsmodels para ANOVA y Tukey ---
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# --- Librerías específicas ---
import pingouin as pg  # pruebas estadísticas (e.g. kruskal, dunn)
from dython.nominal import identify_nominal_columns, identify_numeric_columns, correlation_ratio
from statsmodels.stats.diagnostic import het_breuschpagan
from sklearn.utils import resample
from scipy.stats import shapiro, probplot

# %% [markdown]
# # **Sección 1 - Cargue y transformación de dataset**

# %%
#Lectura de datos
df = pd.read_excel('prueba.xlsx', header=8)
pd.set_option('display.max_columns', None)

# %%
# Crear dataset para análisis
df_analysis = df.copy() 

# Renombrar columnas para facilitar análisis
df_analysis.rename(columns={
    '2 company size': 'Company size',
    '9 Last Year Sales': 'Last year sales',
    '3 Age of the company:': 'Age of company',
    '4 Geographic reach location:': 'Geographic reach location',
    '5 R&D Expenditure (Research and Development):': 'R&D expenditure',
    '6 new products sales:': 'New products sales',
    '7 Number of patents/innovations:': 'Number of patents innovations',
    '8 Annual growth:': 'Annual growth',
    "1 industry/sector:": "Industry/Sector"
}, inplace=True)

# Eliminar duplicados por empresa
df_analysis = df_analysis.drop_duplicates(subset=['Company'])

# Seleccionar columnas 1 a 15
df_analysis = df_analysis.iloc[:, 1:15]

# Dividir la columna de industria y sector
df_analysis[['Industry', 'Sector']] = df_analysis['Industry/Sector'].str.split(', ', n=1, expand=True)

# Limpiar y convertir 'New products sales'
df_analysis['New products sales'] = df_analysis['New products sales'].astype(str)
df_analysis['New products sales'] = df_analysis['New products sales'].str.replace(r'[\$,]', '', regex=True)
df_analysis['New products sales'] = df_analysis['New products sales'].str.replace('.', '', regex=False)
df_analysis['New products sales'] = df_analysis['New products sales'].astype(float)

# Cambiar a inglés los valores de las columnas "Industry" y "Sector"
# Diccionario de traducción
industry_translation = {
    "Manufactura": "Manufacturing",
    "Servicios": "Services",
    "Comercio": "Commerce"
}

sector_translation = {
    "Moda": "Fashion",
    "Construcción": "Construction",
    "Comidas y bebidas": "Food and Beverages",
    "Educación": "Education",
    "Automotor": "Automotive",
    "Belleza y cuidado personal": "Beauty and Personal Care",
    "Deportes": "Sports",
    "Empaques": "Packaging",
    "Energía": "Energy",
    "Ferroelectrico": "Ferroelectric",
    "Mejora de procesos": "Process Improvement",
    "Papelería": "Stationery",
    "Tecnología": "Technology",
    "Textiles": "Textiles",
    "Transporte y logística": "Transport and Logistics"
}

# Aplicar la traducción a Industry
df_analysis['Industry'] = df_analysis['Industry'].replace(industry_translation)

# Limpieza previa opcional: quitar espacios extra si hay
df_analysis['Sector'] = df_analysis['Sector'].str.strip()
# Unificar manualmente los duplicados (si hay diferencias de acento, mayúsculas, etc.)
df_analysis['Sector'] = df_analysis['Sector'].replace("Tecnología", "Tecnología")
# Aplicar traducción a sector
df_analysis['Sector'] = df_analysis['Sector'].replace(sector_translation)

# Cambiar a millones algunas variables
df_analysis['R&D expenditure (millions)']=df_analysis['R&D expenditure']/1_000_000
df_analysis['New products sales (millions)']=df_analysis['New products sales']/1_000_000
df_analysis['Last year sales (millions)']=df_analysis['Last year sales']/1_000_000

# Hacer transformación a porcentaje de variable "Annual growth"
df_analysis['Annual growth'] = df_analysis['Annual growth'].astype(float)
df_analysis['Annual growth (%)'] = (df_analysis['Annual growth'] * 100).round(1).astype(str) + '%'

# Vista previa
df_analysis.head(5)
# Out:
#    Company_number LT \nLeader of Team)\n \nor\n \nTM \n(Team Member)    CODE  \
# 0               1                                                 LT  C01-LT
# 2               2                                                 LT  C02-LT
# 4               3                                                 LT  C03-LT
# 6               4                                                 LT  C04-LT
# 8               5                                                 LT  C05-LT
#
#         Industry                    Industry/Sector Company size  \
# 0  Manufacturing                  Manufactura, Moda          Big
# 2       Services       Servicios, Comidas y bebidas          Big
# 4  Manufacturing                  Manufactura, Moda          Big
# 6       Services  Servicios, Transporte y logística       Medium
# 8       Services              Servicios, Tecnología       Medium
#
#    Age of company Age of the company (segment) Geographic reach location  \
# 0              29                    25+ years                  Regional
# 2               6                    5-8 years                  National
# 4               8                    5-8 years                     Local
# 6              23                  15-25 years             International
# 8              25                  15-25 years                  National
#
#    R&D expenditure  New products sales  Number of patents innovations  \
# 0     2.000000e-02        1.785000e+10                             12
# 2     1.037000e+09        2.835000e+09                              8
# 4     0.000000e+00        1.320000e+10                              4
# 6     1.200000e+09        4.800000e+09                              6
# 8     9.625000e+08        3.850000e+09                              4
#
#    Annual growth  Last year sales                   Sector  \
# 0           0.18      85000000000                  Fashion
# 2           0.24      94500000000       Food and Beverages
# 4           0.10     110000000000                  Fashion
# 6           0.15      13450000000  Transport and Logistics
# 8           0.08      19250000000               Technology
#
#    R&D expenditure (millions)  New products sales (millions)  \
# 0                2.000000e-08                        17850.0
# 2                1.037000e+03                         2835.0
# 4                0.000000e+00                        13200.0
# 6                1.200000e+03                         4800.0
# 8                9.625000e+02                         3850.0
#
#    Last year sales (millions) Annual growth (%)
# 0                     85000.0             18.0%
# 2                     94500.0             24.0%
# 4                    110000.0             10.0%
# 6                     13450.0             15.0%
# 8                     19250.0              8.0%

# %% [markdown]
# # **Sección 2 - Análisis Univariado**

# %% [markdown]
# ## **2.1 Industry**

# %%
df_analysis['Industry'].describe()
# Out:
# count                28
# unique                3
# top       Manufacturing
# freq                 14
# Name: Industry, dtype: object

# %%
tabla_freq=(pd.crosstab(index=df_analysis["Industry"],columns="count")).reset_index()
tabla_freq['Freq. Rel.']=tabla_freq['count']/sum(tabla_freq['count'])
tabla_freq.rename(columns={'count':'Freq. Abs.'},inplace=True)
tabla_freq=tabla_freq.sort_values(by='Freq. Abs.',ascending=False).reset_index(drop=True)
tabla_freq
# Out:
# col_0       Industry  Freq. Abs.  Freq. Rel.
# 0      Manufacturing          14    0.500000
# 1           Services           8    0.285714
# 2           Commerce           6    0.214286

# %%
fig_torta = plt.figure() 
ax = fig_torta.add_axes([0,0,1,1])
plt.pie(tabla_freq["Freq. Rel."], labels=tabla_freq["Industry"],autopct='%1.1f%%',startangle=90)
plt.title("Distribution of the Industry variable", fontweight='bold')
plt.show()

# %% [markdown]
# ## **2.2 Sector**

# %%
df_analysis['Sector'].describe()
# Out:
# count          28
# unique         15
# top       Fashion
# freq            8
# Name: Sector, dtype: object

# %%
tabla_freq=(pd.crosstab(index=df_analysis["Sector"],columns="count")).reset_index()
tabla_freq['Freq. Rel.']=tabla_freq['count']/sum(tabla_freq['count'])
tabla_freq.rename(columns={'count':'Freq. Abs.'},inplace=True)
tabla_freq=tabla_freq.sort_values(by='Freq. Abs.',ascending=False).reset_index(drop=True)
tabla_freq
# Out:
# col_0                    Sector  Freq. Abs.  Freq. Rel.
# 0                       Fashion           8    0.285714
# 1                  Construction           4    0.142857
# 2                     Education           2    0.071429
# 3            Food and Beverages           2    0.071429
# 4                    Technology           2    0.071429
# 5                    Automotive           1    0.035714
# 6      Beauty and Personal Care           1    0.035714
# 7                        Energy           1    0.035714
# 8                 Ferroelectric           1    0.035714
# 9                     Packaging           1    0.035714
# 10          Process Improvement           1    0.035714
# 11                       Sports           1    0.035714
# 12                   Stationery           1    0.035714
# 13                     Textiles           1    0.035714
# 14      Transport and Logistics           1    0.035714

# %%
# Recalcular sector_freq_sorted por si se perdió en el contexto
sector_freq = df_analysis['Sector'].value_counts().reset_index()
sector_freq.columns = ['Sector', 'frecuencia_absoluta']
sector_freq['frecuencia_relativa'] = sector_freq['frecuencia_absoluta'] / sector_freq['frecuencia_absoluta'].sum()
sector_freq_sorted = sector_freq.sort_values(by="frecuencia_relativa", ascending=False)

# Crear el gráfico de barras con etiquetas al extremo derecho y en color blanco
fig, ax = plt.subplots(figsize=(12, 6))
bars = ax.barh(
    sector_freq_sorted["Sector"],
    sector_freq_sorted["frecuencia_relativa"] * 100,
    color="#4682B4"
)

# Añadir etiquetas en blanco al final de cada barra
for bar in bars:
    width = bar.get_width()
    ax.text(width - 1, bar.get_y() + bar.get_height() / 2,
            f"{width:.1f}%", va='center', ha='right', color='white', fontsize=9, fontweight='bold')

# Configuración estética
ax.set_xlabel("Relative frequency (%)")
ax.set_title("Distribution of the Sector variable", fontsize=15, fontweight='bold')
ax.invert_yaxis()
ax.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **2.3 Age of the company**

# %%
df_analysis['Age of company'].describe()
# Out:
# count    28.000000
# mean     19.142857
# std      12.270755
# min       5.000000
# 25%       7.750000
# 50%      17.500000
# 75%      25.500000
# max      47.000000
# Name: Age of company, dtype: float64

# %%
# Create figure with two subplots (one for boxplot and one for histogram)
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10, 6))
fig.suptitle("Distribution of Company Age",
             fontsize=14, fontweight='bold')

# Boxplot
sns.boxplot(x=df_analysis['Age of company'], color="steelblue", ax=axs[0])
axs[0].set_xlabel("")
# axs[0].set_title("Boxplot")

# Histogram with KDE
sns.histplot(df_analysis['Age of company'], kde=True, color="steelblue", ax=axs[1])
axs[1].set_xlabel("Company Age")
# axs[1].set_title("Histogram with KDE")

plt.tight_layout(rect=[0, 0, 1, 0.95])  # leave space for the main title
plt.show()

# %% [markdown]
# ## **2.4 Geographic location**

# %%
df_analysis['Geographic reach location'].describe()
# Out:
# count        28
# unique        4
# top       Local
# freq         14
# Name: Geographic reach location, dtype: object

# %%
tabla_freq=(pd.crosstab(index=df_analysis["Geographic reach location"],columns="count")).reset_index()
tabla_freq['Freq. Rel.']=tabla_freq['count']/sum(tabla_freq['count'])
tabla_freq.rename(columns={'count':'Freq. Abs.'},inplace=True)
tabla_freq=tabla_freq.sort_values(by='Freq. Abs.',ascending=False).reset_index(drop=True)
tabla_freq
# Out:
# col_0 Geographic reach location  Freq. Abs.  Freq. Rel.
# 0                         Local          14    0.500000
# 1                      National           9    0.321429
# 2                 International           3    0.107143
# 3                      Regional           2    0.071429

# %%
fig_pie = plt.figure() 
ax = fig_pie.add_axes([0, 0, 1, 1])

plt.pie(tabla_freq["Freq. Rel."],
        labels=tabla_freq["Geographic reach location"],
        autopct='%1.1f%%',
        startangle=90)

plt.title("Distribution of the Companies Geographic Reach", fontweight='bold')
plt.show()

# %% [markdown]
# ## **2.5 R&D Expenditure**

# %%
df_analysis['R&D expenditure (millions)'].describe()
# Out:
# count      28.000000
# mean      249.546429
# std       428.326091
# min         0.000000
# 25%         0.000000
# 50%        72.500000
# 75%       121.125000
# max      1424.000000
# Name: R&D expenditure (millions), dtype: float64

# %%
# Create figure with two subplots (one for boxplot and one for histogram)
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10, 6))
fig.suptitle("R&D expenditure (millions)",
             fontsize=14, fontweight='bold')

# Boxplot
sns.boxplot(x=df_analysis['R&D expenditure (millions)'], color="steelblue", ax=axs[0])
axs[0].set_xlabel("")
# axs[0].set_title("Boxplot")

# Histogram with KDE
sns.histplot(df_analysis['R&D expenditure (millions)'], kde=True, color="steelblue", ax=axs[1])
axs[1].set_xlabel("R&D expenditure (millions)")
# axs[1].set_title("Histogram with KDE")

plt.tight_layout(rect=[0, 0, 1, 0.95])  # leave space for the main title
plt.show()

# %% [markdown]
# ## **2.5 New product sales**

# %%
df_analysis['New products sales (millions)'].describe()
# Out:
# count       28.000000
# mean      4657.911286
# std       7936.571830
# min          0.000000
# 25%         94.125000
# 50%       2118.000000
# 75%       4598.437500
# max      36200.766000
# Name: New products sales (millions), dtype: float64

# %%
# Create figure with two subplots (one for boxplot and one for histogram)
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10, 6))
fig.suptitle("New products sales (millions)",
             fontsize=14, fontweight='bold')

# Boxplot
sns.boxplot(x=df_analysis['New products sales (millions)'], color="steelblue", ax=axs[0])
axs[0].set_xlabel("")
# axs[0].set_title("Boxplot")

# Histogram with KDE
sns.histplot(df_analysis['New products sales (millions)'], kde=True, color="steelblue", ax=axs[1])
axs[1].set_xlabel("New products sales (millions)")
# axs[1].set_title("Histogram with KDE")

plt.tight_layout(rect=[0, 0, 1, 0.95])  # leave space for the main title
plt.show()

# %% [markdown]
# ## **2.6 Number of patents innovations**

# %%
df_analysis['Number of patents innovations'].describe()
# Out:
# count    28.000000
# mean      3.285714
# std       2.706058
# min       0.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max      12.000000
# Name: Number of patents innovations, dtype: float64

# %%
# Create figure with two subplots (one for boxplot and one for histogram)
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10, 6))
fig.suptitle("Number of patents innovations",
             fontsize=14, fontweight='bold')

# Boxplot
sns.boxplot(x=df_analysis['Number of patents innovations'], color="steelblue", ax=axs[0])
axs[0].set_xlabel("")
# axs[0].set_title("Boxplot")

# Histogram with KDE
sns.histplot(df_analysis['Number of patents innovations'], kde=True, color="steelblue", ax=axs[1])
axs[1].set_xlabel("Number of patents innovations")
# axs[1].set_title("Histogram with KDE")

plt.tight_layout(rect=[0, 0, 1, 0.95])  # leave space for the main title
plt.show()

# %% [markdown]
# ## **2.7 Last year sales (millions)**

# %%
df_analysis['Last year sales (millions)'].describe()
# Out:
# count        28.000000
# mean      29441.167953
# std       34884.050470
# min         120.000000
# 25%        4567.500000
# 50%       14770.000000
# 75%       40937.500000
# max      110000.000000
# Name: Last year sales (millions), dtype: float64

# %%
# Create figure with two subplots (one for boxplot and one for histogram)
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10, 6))
fig.suptitle("Last year sales (millions)",
             fontsize=14, fontweight='bold')

# Boxplot
sns.boxplot(x=df_analysis['Last year sales (millions)'], color="steelblue", ax=axs[0])
axs[0].set_xlabel("")
# axs[0].set_title("Boxplot")

# Histogram with KDE
sns.histplot(df_analysis['Last year sales (millions)'], kde=True, color="steelblue", ax=axs[1])
axs[1].set_xlabel("Last year sales (millions)")
# axs[1].set_title("Histogram with KDE")

plt.tight_layout(rect=[0, 0, 1, 0.95])  # leave space for the main title
plt.show()

# %% [markdown]
# ## **2.8 Company size**

# %%
df_analysis['Company size'].describe()
# Out:
# count         28
# unique         4
# top       Medium
# freq          15
# Name: Company size, dtype: object

# %%
tabla_freq=(pd.crosstab(index=df_analysis["Company size"],columns="count")).reset_index()
tabla_freq['Freq. Rel.']=tabla_freq['count']/sum(tabla_freq['count'])
tabla_freq.rename(columns={'count':'Freq. Abs.'},inplace=True)
tabla_freq=tabla_freq.sort_values(by='Freq. Abs.',ascending=False).reset_index(drop=True)
tabla_freq
# Out:
# col_0 Company size  Freq. Abs.  Freq. Rel.
# 0           Medium          15    0.535714
# 1            Small           5    0.178571
# 2              Big           4    0.142857
# 3            Micro           4    0.142857

# %%
fig_pie = plt.figure() 
ax = fig_pie.add_axes([0, 0, 1, 1])

plt.pie(tabla_freq["Freq. Rel."],
        labels=tabla_freq["Company size"],
        autopct='%1.1f%%',
        startangle=90)

plt.title("Distribution of the company size", fontweight='bold')
plt.show()

# %% [markdown]
# ## **2.9 Annual growth**

# %%
df_analysis["Annual growth"].describe()
# Out:
# count    28.000000
# mean      0.125000
# std       0.097696
# min      -0.050000
# 25%       0.050000
# 50%       0.120000
# 75%       0.200000
# max       0.400000
# Name: Annual growth, dtype: float64

# %%
# Create figure with two subplots (one for boxplot and one for histogram)
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10, 6))
fig.suptitle("Annual growth",
             fontsize=14, fontweight='bold')

# Boxplot
sns.boxplot(x=df_analysis['Annual growth'], color="steelblue", ax=axs[0])
axs[0].set_xlabel("")
# axs[0].set_title("Boxplot")

# Histogram with KDE
sns.histplot(df_analysis['Annual growth'], kde=True, color="steelblue", ax=axs[1])
axs[1].set_xlabel("Annual growth")
# axs[1].set_title("Histogram with KDE")

plt.tight_layout(rect=[0, 0, 1, 0.95])  # leave space for the main title
plt.show()

# %% [markdown]
# # **Sección 2 - Aplicación de modelo GRM y análisis bivariados**

# %% [markdown]
# ## **2.1 Cargue de datos y ajuste de datasets**

# %%
# Cargue de datos de resultados del modelo GRM
df_grm=pd.read_excel("indices_grm_dimensiones_estandarizados.xlsx")

# Traer al dataset de resultados del modelo GRM las variables de  caracterización de las empresas
df_analysis_multivariate = df_grm.merge(
    df[["Company",'CODE',
       'Industry', '1 industry/sector:', '2 company size',
       '3 Age of the company:', 'Age of the company (segment)',
       '4 Geographic reach location:',
       '5 R&D Expenditure (Research and Development):',
       '6 new products sales:', '7 Number of patents/innovations:',
       '8 Annual growth:', '9 Last Year Sales']],
    on='CODE',
    how='left'
)

# %%
# Renombrar columnas para facilitar análisis
df_analysis_multivariate.rename(columns={
    '2 company size': 'Company size',
    '9 Last Year Sales': 'Last year sales',
    '3 Age of the company:': 'Age of company',
    '4 Geographic reach location:': 'Geographic reach location',
    '5 R&D Expenditure (Research and Development):': 'R&D expenditure',
    '6 new products sales:': 'New products sales',
    '7 Number of patents/innovations:': 'Number of patents innovations',
    '8 Annual growth:': 'Annual growth',
    "1 industry/sector:": "Industry/Sector"
}, inplace=True)

# Dividir la columna de industria y sector
df_analysis_multivariate[['Industry', 'Sector']] = df_analysis_multivariate['Industry/Sector'].str.split(', ', n=1, expand=True)

# Limpiar y convertir 'New products sales'
df_analysis_multivariate['New products sales'] = df_analysis_multivariate['New products sales'].astype(str)
df_analysis_multivariate['New products sales'] = df_analysis_multivariate['New products sales'].str.replace(r'[\$,]', '', regex=True)
df_analysis_multivariate['New products sales'] = df_analysis_multivariate['New products sales'].str.replace('.', '', regex=False)
df_analysis_multivariate['New products sales'] = df_analysis_multivariate['New products sales'].astype(float)

# Cambiar a inglés los valores de las columnas "Industry" y "Sector"
# Diccionario de traducción
industry_translation = {
    "Manufactura": "Manufacturing",
    "Servicios": "Services",
    "Comercio": "Commerce"
}

sector_translation = {
    "Moda": "Fashion",
    "Construcción": "Construction",
    "Comidas y bebidas": "Food and Beverages",
    "Educación": "Education",
    "Automotor": "Automotive",
    "Belleza y cuidado personal": "Beauty and Personal Care",
    "Deportes": "Sports",
    "Empaques": "Packaging",
    "Energía": "Energy",
    "Ferroelectrico": "Ferroelectric",
    "Mejora de procesos": "Process Improvement",
    "Papelería": "Stationery",
    "Tecnología": "Technology",
    "Textiles": "Textiles",
    "Transporte y logística": "Transport and Logistics"
}

# Aplicar la traducción a Industry
df_analysis_multivariate['Industry'] = df_analysis_multivariate['Industry'].replace(industry_translation)

# Limpieza previa opcional: quitar espacios extra si hay
df_analysis_multivariate['Sector'] = df_analysis_multivariate['Sector'].str.strip()
# Unificar manualmente los duplicados (si hay diferencias de acento, mayúsculas, etc.)
df_analysis_multivariate['Sector'] = df_analysis_multivariate['Sector'].replace("Tecnología", "Tecnología")
# Aplicar traducción a sector
df_analysis_multivariate['Sector'] = df_analysis_multivariate['Sector'].replace(sector_translation)

# Cambiar a millones algunas variables
df_analysis_multivariate['R&D expenditure (millions)']=df_analysis_multivariate['R&D expenditure']/1_000_000
df_analysis_multivariate['New products sales (millions)']=df_analysis_multivariate['New products sales']/1_000_000
df_analysis_multivariate['Last year sales (millions)']=df_analysis_multivariate['Last year sales']/1_000_000

# Hacer transformación a porcentaje de variable "Annual growth"
df_analysis_multivariate['Annual growth'] = df_analysis_multivariate['Annual growth'].astype(float)
df_analysis_multivariate['Annual growth (%)'] = (df_analysis_multivariate['Annual growth'] * 100).round(1).astype(str) + '%'

# Vista previa
df_analysis_multivariate.head(5)
# Out:
#      CODE  Indice_Sensing  Indice_Seizing  Indice_Transformation  \
# 0  C01-LT        1.584394        1.302203               1.820393
# 1  C01-TM        1.613900        1.308076               1.837790
# 2  C02-LT        0.475348        0.439359               0.792505
# 3  C02-TM        0.515720        0.432376               0.798164
# 4  C03-LT        0.421892        0.641390               0.577742
#
#    Indice_Sensing_Z  Indice_Seizing_Z  Indice_Transformation_Z Company  \
# 0          1.584908          1.307669                 1.822736     C01
# 1          1.614417          1.313544                 1.840152     C01
# 2          0.475718          0.444613                 0.793801     C02
# 3          0.516096          0.437629                 0.799466     C02
# 4          0.422256          0.646694                 0.578820     C03
#
#         Industry               Industry/Sector Company size  Age of company  \
# 0  Manufacturing             Manufactura, Moda          Big              29
# 1  Manufacturing             Manufactura, Moda          Big              29
# 2       Services  Servicios, Comidas y bebidas          Big               6
# 3       Services  Servicios, Comidas y bebidas          Big               6
# 4  Manufacturing             Manufactura, Moda          Big               8
#
#   Age of the company (segment) Geographic reach location  R&D expenditure  \
# 0                    25+ years                  Regional     2.000000e-02
# 1                    25+ years                  Regional     2.000000e-02
# 2                    5-8 years                  National     1.037000e+09
# 3                    5-8 years                  National     1.037000e+09
# 4                    5-8 years                     Local     0.000000e+00
#
#    New products sales  Number of patents innovations  Annual growth  \
# 0        1.785000e+10                             12           0.18
# 1        1.785000e+10                             12           0.18
# 2        2.835000e+09                              8           0.24
# 3        2.835000e+09                              8           0.24
# 4        1.320000e+10                              4           0.10
#
#    Last year sales              Sector  R&D expenditure (millions)  \
# 0      85000000000             Fashion                2.000000e-08
# 1      85000000000             Fashion                2.000000e-08
# 2      94500000000  Food and Beverages                1.037000e+03
# 3      94500000000  Food and Beverages                1.037000e+03
# 4     110000000000             Fashion                0.000000e+00
#
#    New products sales (millions)  Last year sales (millions) Annual growth (%)
# 0                        17850.0                     85000.0             18.0%
# 1                        17850.0                     85000.0             18.0%
# 2                         2835.0                     94500.0             24.0%
# 3                         2835.0                     94500.0             24.0%
# 4                        13200.0                    110000.0             10.0%

# %%
# Promediar los valores de variables latentes por cada compañía
# Agrupar por empresa y calcular promedios de los índices latentes y sus z-scores
df_analysis_multivariate_final = df_analysis_multivariate.groupby('Company').agg({
    'Indice_Sensing': 'mean',
    'Indice_Seizing': 'mean',
    'Indice_Transformation': 'mean',
    'Indice_Sensing_Z': 'mean',
    'Indice_Seizing_Z': 'mean',
    'Indice_Transformation_Z': 'mean',
    'Company size': 'first',
    'Industry': 'first',
    'Sector': 'first',
    "Last year sales": 'first',
    "Age of company":"first",
    "Geographic reach location": 'first',
    "R&D expenditure": 'first',
    "New products sales": 'first',
    "Number of patents innovations": 'first',
    "Annual growth": 'first'
}).reset_index()

# %%
df_analysis_multivariate_final.rename(columns={
    'Indice_Sensing': 'Latent_sensing',
    'Indice_Seizing': 'Latent_seizing',
    'Indice_Transformation': 'Latent_transformation',
    'Indice_Sensing_Z': 'Latent_sensing_Z',
    'Indice_Seizing_Z': 'Latent_seizing_Z',
    'Indice_Transformation_Z': 'Latent_transformation_Z',
}, inplace=True)

# %%
df_analysis_multivariate_final
# Out:
#    Company  Latent_sensing  Latent_seizing  Latent_transformation  \
# 0      C01        1.599147        1.305140               1.829091
# 1      C02        0.495534        0.435867               0.795335
# 2      C03        1.566232        1.703583               1.637924
# 3      C04       -0.467213       -0.401244              -0.331791
# 4      C05        0.318504        0.533603               0.398109
# 5      C06       -1.502069       -1.351313              -1.699216
# 6      C07        0.241241        0.006293              -0.390087
# 7      C08       -0.200324       -0.130438               0.592535
# 8      C09        2.190476        2.629447               2.181530
# 9      C10        0.501075       -0.009984               0.578918
# 10     C11       -0.042040       -0.580320              -0.626904
# 11     C12       -0.322200       -0.269024              -0.545377
# 12     C13       -0.221294       -0.300631              -0.125929
# 13     C14       -0.396047       -0.904418              -0.450626
# 14     C15       -0.246015       -0.313822               0.256988
# 15     C16       -0.016718        0.071475              -0.164969
# 16     C17       -0.807466       -0.273281              -0.790574
# 17     C18       -0.419506       -0.099065              -0.590558
# 18     C19       -1.001584       -0.821911              -1.429304
# 19     C20        0.818837        0.622122               0.643801
# 20     C21        0.019073        0.136457               0.214117
# 21     C22        0.295721        0.274236              -0.073095
# 22     C23       -0.436500       -0.090359              -0.236842
# 23     C24       -1.217122       -0.201687              -0.239376
# 24     C25       -0.296984       -0.293261              -0.019235
# 25     C26       -0.078279        0.045598              -0.359533
# 26     C27       -0.222954       -0.092214              -0.648398
# 27     C28       -0.160187       -1.774918              -0.420191
#
#     Latent_sensing_Z  Latent_seizing_Z  Latent_transformation_Z Company size  \
# 0           1.599663          1.310607                 1.831444          Big
# 1           0.495907          0.441121                 0.796633          Big
# 2           1.566743          1.709148                 1.640082          Big
# 3          -0.466963         -0.396196                -0.331641       Medium
# 4           0.318855          0.538881                 0.399003       Medium
# 5          -1.501954         -1.346499                -1.700460       Medium
# 6           0.241581          0.011441                -0.389997       Medium
# 7          -0.200041         -0.125323                 0.593628        Small
# 8           2.191067          2.635239                 2.184242          Big
# 9           0.501449         -0.004840                 0.579997       Medium
# 10         -0.041736         -0.575316                -0.627055        Small
# 11         -0.321933         -0.263944                -0.545444       Medium
# 12         -0.221013         -0.295559                -0.125569       Medium
# 13         -0.395789         -0.899494                -0.450597       Medium
# 14         -0.245737         -0.308753                 0.257738        Small
# 15         -0.016411          0.076639                -0.164649        Small
# 16         -0.807260         -0.268201                -0.790891        Micro
# 17         -0.419251         -0.093943                -0.590672        Micro
# 18         -1.001404         -0.816966                -1.430272       Medium
# 19          0.819252          0.627421                 0.644945       Medium
# 20          0.019385          0.141637                 0.214824       Medium
# 21          0.296069          0.279450                -0.072682       Medium
# 22         -0.436247         -0.085234                -0.236595        Small
# 23         -1.216969         -0.196590                -0.239131        Micro
# 24         -0.296713         -0.288187                -0.018767       Medium
# 25         -0.077980          0.050756                -0.359411       Medium
# 26         -0.222673         -0.087091                -0.648571        Micro
# 27         -0.159899         -1.770207                -0.420131       Medium
#
#          Industry                    Sector  Last year sales  Age of company  \
# 0   Manufacturing                   Fashion      85000000000              29
# 1        Services        Food and Beverages      94500000000               6
# 2   Manufacturing                   Fashion     110000000000               8
# 3        Services   Transport and Logistics      13450000000              23
# 4        Services                Technology      19250000000              25
# 5   Manufacturing              Construction      71200000000              30
# 6   Manufacturing              Construction      64000000000              40
# 7   Manufacturing                   Fashion       3270000000              12
# 8        Commerce             Ferroelectric     110000000000              24
# 9   Manufacturing                   Fashion      14760000000              21
# 10       Commerce                  Textiles      14780000000              20
# 11  Manufacturing                   Fashion      55000000000              16
# 12       Commerce                    Sports      19230000000              27
# 13  Manufacturing                   Fashion       8325000000              12
# 14       Commerce                Technology       2550000000               5
# 15       Services                Automotive       1560000000               5
# 16  Manufacturing                   Fashion        120000000               5
# 17       Commerce  Beauty and Personal Care       1450000000               6
# 18  Manufacturing                 Packaging      36250000000              46
# 19       Services        Food and Beverages      12450000000              18
# 20  Manufacturing              Construction      15943979000              47
# 21       Services                 Education       5786273819              21
# 22  Manufacturing                   Fashion       9200000000              11
# 23       Services                 Education        185000000               6
# 24  Manufacturing              Construction      26242449862              16
# 25  Manufacturing                    Energy       5000000000              33
# 26       Services       Process Improvement        850000000               7
# 27       Commerce                Stationery      24000000000              17
#
#    Geographic reach location  R&D expenditure  New products sales  \
# 0                   Regional     2.000000e-02        1.785000e+10
# 1                   National     1.037000e+09        2.835000e+09
# 2                      Local     0.000000e+00        1.320000e+10
# 3              International     1.200000e+09        4.800000e+09
# 4                   National     9.625000e+08        3.850000e+09
# 5                   National     1.424000e+09        1.780000e+10
# 6                   National     1.000000e+07        3.620077e+10
# 7                   National     9.810000e+07        3.270000e+08
# 8              International     1.200000e+08        2.600000e+08
# 9                      Local     1.000000e+08        1.476000e+09
# 10                     Local     0.000000e+00        4.434000e+09
# 11                     Local     0.000000e+00        3.300000e+09
# 12                     Local     9.615000e+08        5.769000e+09
# 13                     Local     0.000000e+00        5.000000e+08
# 14                  Regional     1.200000e+07        7.650000e+07
# 15                     Local     1.092000e+08        0.000000e+00
# 16             International     3.500000e+06        7.200000e+07
# 17                  National     0.000000e+00        0.000000e+00
# 18                     Local     0.000000e+00        4.531250e+09
# 19                     Local     1.245000e+08        6.225000e+08
# 20                  National     8.500000e+07        0.000000e+00
# 21                  National     3.000000e+07        1.000000e+08
# 22                     Local     4.600000e+08        2.760000e+09
# 23                     Local     0.000000e+00        3.500000e+07
# 24                  National     9.000000e+07        3.730000e+09
# 25                     Local     1.000000e+08        1.300000e+08
# 26                     Local     6.000000e+07        2.500000e+06
# 27                     Local     0.000000e+00        5.760000e+09
#
#     Number of patents innovations  Annual growth
# 0                              12           0.18
# 1                               8           0.24
# 2                               4           0.10
# 3                               6           0.15
# 4                               4           0.08
# 5                               4           0.26
# 6                               3           0.20
# 7                               3           0.12
# 8                               2           0.14
# 9                               3          -0.03
# 10                              4           0.03
# 11                              9           0.23
# 12                              3           0.15
# 13                              1          -0.05
# 14                              1           0.05
# 15                              1           0.40
# 16                              3           0.05
# 17                              0           0.20
# 18                              5           0.05
# 19                              2           0.15
# 20                              2           0.20
# 21                              1           0.10
# 22                              0           0.12
# 23                              2           0.08
# 24                              3           0.05
# 25                              2           0.01
# 26                              2           0.20
# 27                              2           0.04

# %% [markdown]
# ## **2.2 Análisis bivariados - Índice Sensing**

# %% [markdown]
# ### **2.2.1 Tamaño de la empresa**

# %% [markdown]
# #### **Comprobación de normalidad de los datos**

# %%
# Aplicar Shapiro-Wilk a cada grupo
for group in df_analysis_multivariate_final['Company size'].unique():
    datos_grupo = df_analysis_multivariate_final[df_analysis_multivariate_final['Company size'] == group]['Latent_sensing']
    stat, p = shapiro(datos_grupo)
    print(f"\nGrupo: {group}")
    print(f"Estadístico Shapiro-Wilk: {stat:.4f}, p-valor: {p:.4f}")
    if p < 0.05:
        print("→ No es normal (rechaza H0)")
    else:
        print("→ Normal (no rechaza H0)")
# Out:
# Grupo: Big
# Estadístico Shapiro-Wilk: 0.9166, p-valor: 0.5178
# → Normal (no rechaza H0)
#
# Grupo: Medium
# Estadístico Shapiro-Wilk: 0.9561, p-valor: 0.6249
# → Normal (no rechaza H0)
#
# Grupo: Small
# Estadístico Shapiro-Wilk: 0.9295, p-valor: 0.5929
# → Normal (no rechaza H0)
#
# Grupo: Micro
# Estadístico Shapiro-Wilk: 0.9628, p-valor: 0.7965
# → Normal (no rechaza H0)

# %% [markdown]
# #### **Comprobación de homogeneidad de varianzas**

# %%
# Agrupar los datos por grupo
grupos = df_analysis_multivariate_final['Company size'].unique()
datos_por_grupo = [df_analysis_multivariate_final[df_analysis_multivariate_final['Company size'] == g]['Latent_sensing'] for g in grupos]

# Aplicar prueba de Levene
stat, p = levene(*datos_por_grupo)
print(f"Estadístico Levene: {stat:.4f}, p-valor: {p:.4f}")

if p < 0.05:
    print("→ Varianzas diferentes (rechaza H0)")
else:
    print("→ Varianzas iguales (no rechaza H0)")
# Out:
# Estadístico Levene: 0.9367, p-valor: 0.4383
# → Varianzas iguales (no rechaza H0)

# %% [markdown]
# #### **Aplicación de pruebas estadísticas para revisión de diferencias entre medianas**

# %%
# 1. Classical ANOVA
groups = df_analysis_multivariate_final.groupby('Company size')['Latent_sensing'].apply(list)
f_stat, p_value = f_oneway(*groups)

print("\nClassical ANOVA results:")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# 2. Check if significant
if p_value < 0.05:
    print("\nANOVA is significant (p < 0.05). Applying Tukey HSD test...")

    # 3. Tukey HSD post-hoc test
    tukey = pairwise_tukeyhsd(endog=df_analysis_multivariate_final['Latent_sensing'],
                              groups=df_analysis_multivariate_final['Company size'],
                              alpha=0.05)
    tukey_summary = pd.DataFrame(data=tukey.summary().data[1:], columns=tukey.summary().data[0])
    tukey_summary['Interpretation'] = tukey_summary['p-adj'].apply(lambda x: 'Different' if x < 0.05 else 'Equal')

    # 4. Compute medians by group and sort
    medians = df_analysis_multivariate_final.groupby('Company size')['Latent_sensing'].median().reset_index()
    category_order = medians.sort_values('Latent_sensing', ascending=False)['Company size'].tolist()

    # 5. Create figure (boxplot + table)
    fig, ax = plt.subplots(2, 1, figsize=(8, 8), gridspec_kw={'height_ratios': [3, 1]})

    sns.boxplot(x='Company size', y='Latent_sensing', data=df_analysis_multivariate_final,
                ax=ax[0], palette="Set2", order=category_order)
    ax[0].set_title("Sensing by Company Size")
    ax[0].set_xlabel("Company Size")
    ax[0].set_ylabel("Latent Variable (Sensing)")

    # Annotate medians
    for i, row in medians.iterrows():
        idx = category_order.index(row['Company size'])
        offset = 0.05
        ax[0].text(idx, row['Latent_sensing'] + offset, 
                   f"{row['Latent_sensing']:.2f}", 
                   ha='center', va='bottom', fontweight='bold', color='black',
                   bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.05', linewidth=0.3))

    # 6. Add table below the plot
    table = tukey_summary[['group1', 'group2', 'Interpretation']]
    ax[1].axis('off')
    table_text = table.values.tolist()
    column_labels = ['Group 1', 'Group 2', 'Comparison']
    ax[1].table(cellText=table_text, colLabels=column_labels, loc='center', cellLoc='center')

    plt.tight_layout()
    plt.show()

else:
    print("\nANOVA is not significant (p ≥ 0.05). Tukey HSD test and plot will not be generated.")
# Out:
# Classical ANOVA results:
# F-statistic: 12.5298
# P-value: 0.0000
#
# ANOVA is significant (p < 0.05). Applying Tukey HSD test...
# C:\Users\monte\AppData\Local\Temp\ipykernel_11732\3066959377.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Company size', y='Latent_sensing', data=df_analysis_multivariate_final,

# %% [markdown]
# ### **2.2.2 Ventas de la empresa**

# %%
df_analysis_multivariate_final["Last year sales"]=df_analysis_multivariate_final["Last year sales"]/1_000_000

# %%
# Pearson correlation coefficient and p-value calculation
r, p_value = pearsonr(df_analysis_multivariate_final['Latent_sensing'], df_analysis_multivariate_final['Last year sales'])

# Results
print(f"Pearson correlation coefficient: r = {r:.4f}")
print(f"p-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("There is significant evidence of a linear correlation between 'Latent_sensing' and 'Last year sales'.")
else:
    print("No significant evidence of a linear correlation was found between 'Latent_sensing' and 'Last year sales'.")

# Visualization
plt.figure(figsize=(8, 6))
sns.regplot(data=df_analysis_multivariate_final, x='Last year sales', y='Latent_sensing', ci=95, line_kws={'color': 'red'})
plt.title(f"Correlation between Latent Variable (Sensing) and Last Year Sales\nr = {r:.2f}, p = {p_value:.4f}")
plt.xlabel("Last Year Sales")
plt.ylabel("Latent variable (Sensing)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Pearson correlation coefficient: r = 0.5802
# p-value: 0.0012
# There is significant evidence of a linear correlation between 'Latent_sensing' and 'Last year sales'.

# %%
df_promedio_empresa_corr=df_analysis_multivariate_final.copy()

# Cammbio de nombre de Indice_Sensing
df_promedio_empresa_corr.rename(columns={'Latent_sensing': 'Latent variable (Sensing)'}, inplace=True)

# Elegir las columnas que se desean analizar
df_promedio_empresa_corr = df_promedio_empresa_corr[["Latent variable (Sensing)","Company size","Last year sales"]]

categorical_features=identify_nominal_columns(df_promedio_empresa_corr)
continuous_features=identify_numeric_columns(df_promedio_empresa_corr)

# %%
from dython.nominal import associations
target_correlation= associations(df_promedio_empresa_corr, display_rows=["Latent variable (Sensing)"], filename= 'target_correlation.png', figsize=(20,5))
# Out:
# C:\Users\monte\AppData\Roaming\Python\Python311\site-packages\dython\nominal.py:736: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   inf_nan.loc[columns[i], columns[j]] = _inf_nan_str(ij)
# C:\Users\monte\AppData\Roaming\Python\Python311\site-packages\dython\nominal.py:737: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   inf_nan.loc[columns[j], columns[i]] = _inf_nan_str(ji)
# C:\Users\monte\AppData\Roaming\Python\Python311\site-packages\dython\nominal.py:736: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   inf_nan.loc[columns[i], columns[j]] = _inf_nan_str(ij)

# %%
df_promedio_empresa_reg_lineal = df_analysis_multivariate_final[["Latent_sensing","Last year sales"]]

x=df_promedio_empresa_reg_lineal.drop(["Last year sales"], axis=1)
y=df_promedio_empresa_reg_lineal["Last year sales"]
X = sm.add_constant(x) 
model = sm.OLS(y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Last year sales   R-squared:                       0.337
# Model:                            OLS   Adj. R-squared:                  0.311
# Method:                 Least Squares   F-statistic:                     13.20
# Date:                Sun, 15 Jun 2025   Prob (F-statistic):            0.00121
# Time:                        12:32:02   Log-Likelihood:                -326.35
# No. Observations:                  28   AIC:                             656.7
# Df Residuals:                      26   BIC:                             659.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           2.945e+04   5471.517      5.382      0.000    1.82e+04    4.07e+04
# Latent_sensing  2.494e+04   6865.745      3.633      0.001    1.08e+04    3.91e+04
# ==============================================================================
# Omnibus:                        6.971   Durbin-Watson:                   1.727
# Prob(Omnibus):                  0.031   Jarque-Bera (JB):                5.490
# Skew:                           1.060   Prob(JB):                       0.0643
# Kurtosis:                       3.463   Cond. No.                         1.25
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **I) Linealidad**

# %%
# Extrae las columnas Y y X del DataFrame
Y = df_analysis_multivariate_final['Last year sales']
X = df_analysis_multivariate_final['Latent_sensing']

# %%
# Calcula el coeficiente de correlación de Pearson y el valor p
correlation_coefficient, p_value = stats.pearsonr(Y, X)

# nivel de significancia (alpha)
alpha = 0.05

# Comparar el valor p con el nivel de significancia
if p_value < alpha:
    print("Hay evidencia de una relación lineal significativa (p < alpha)")
else:
    print("No hay evidencia de una relación lineal significativa (p >= alpha)")

print(f"Coeficiente de correlación de Pearson: {correlation_coefficient}")
# Out:
# Hay evidencia de una relación lineal significativa (p < alpha)
# Coeficiente de correlación de Pearson: 0.5802331448482477

# %% [markdown]
# Se evidencia una relación lineal positiva y significativa. Aunque el ajuiste del modelo es bajo.

# %% [markdown]
# **II) Independencia de errores**

# %%
errores = result.resid
errores_i_1 = errores[:-1]
errores_i = errores[1:]

plt.scatter(errores_i_1, errores_i,c='blue', marker='o',alpha=0.6)
plt.title('Gráfico de Dispersión de Error(i-1) vs Error(i)')
plt.xlabel('Error (i-1)')
plt.ylabel('Error (i)')
# Out:
# Text(0, 0.5, 'Error (i)')

# %% [markdown]
# En el gráfico anterior se evidencia que la dispersión sigue un patrón de esfericidad, por lo que se puede anticipar la no existencia de autocorrelación en los errores. Sin embargo, se procede a ejecutar una prueba estadística para confirmar lo anterior.
#
# Según lo reportado en la tabla anterior, el estadístico de la prueba de Durbin Watson tiene un valor de 1.727. Las pruebas de hipótesis de esta prueba son las siguientes:
#
# - **H0: cor(e_i,e_{i-1}==0** -> esto es NO hay autocorrelación entre los errores
# - **H1: cor(e_i,e_{i-1}!=0** -> esto es SÍ hay autocorrelación entre los erorres
#
# En este caso el estadístico DW está en el intervalo 1.5 y 2.5, por lo que no se debe rechazar la hipótesis nula de no autocorrelación, lo que permite **evidenciar la no autocorrelación entre los errores**.

# %% [markdown]
# **III) Homocedasticidad**

# %%
# Calcula los valores ajustados del modelo
valores_ajustados = result.fittedvalues

# Gráfico de dispersión de residuos vs valores ajustados
plt.scatter(valores_ajustados, errores, c='blue', marker='o', alpha=0.6)
plt.xlabel('Valores Ajustados')
plt.ylabel('Residuos')
plt.title('Gráfico de Residuos vs. Valores Ajustados')
plt.show()

# %%
# Suponiendo que 'modelo' es tu modelo de regresión ajustado
prueba_homocedasticidad = het_breuschpagan(errores, result.model.exog)

# La prueba devuelve varios valores, puedes ver el p-valor así:
p_valor = prueba_homocedasticidad[3]

print(f"P-valor asociado a la prueba Breusch Pagan: {p_valor}")
# Out:
# P-valor asociado a la prueba Breusch Pagan: 0.5232604103119459

# %% [markdown]
# Las hipótesis asociadas a esta prueba son las siguientes:
#
# - **HO: e_i son homocedásticos** (homogeneidad de la varianza)
# - **H1: e_i no son homocedásticos** (heterogeneidad de la varianza)
#
# En este caso, el p-valor asociado a la prueba de Breusch-Pagan es mayor a un nivel de significancia de 0.05, lo que lleva a aceptar la hipótesis nula de homocedasticidad. En este sentido, se concluye que **el modelo cumple con el supuesto de homocedasticidad en la varianza de los errores**.

# %% [markdown]
# **IV) Normalidad de los residuos**

# %%
sns.histplot(errores, kde=True)
plt.xlabel('Residuos')
plt.ylabel('Frecuencia')
plt.title('Histograma de Residuos')
plt.show()

# %%
# Crear el Q-Q plot
sm.qqplot(errores, line='s')  # 's' = línea de referencia con pendiente 1 (esperada si es normal)
plt.title("Q-Q Plot de los residuos")
plt.show()

# %%
# Aplicar la prueba de Shapiro-Wilk
stat, p = shapiro(errores)

# Mostrar el resultado
print("📊 Prueba de normalidad Shapiro-Wilk")
print(f"Estadístico W: {stat:.4f}")
print(f"Valor p: {p:.4f}")

# Interpretación
if p < 0.05:
    print("❌ Rechazamos H₀: los datos no siguen una distribución normal.")
else:
    print("✅ No se rechaza H₀: no hay evidencia de no normalidad.")
# Out:
# 📊 Prueba de normalidad Shapiro-Wilk
# Estadístico W: 0.8981
# Valor p: 0.0103
# ❌ Rechazamos H₀: los datos no siguen una distribución normal.

# %% [markdown]
# El modelo OLS clásico cumple con todos los supuestos, menos con el de normalidad. En este caso, es necesario aplicar una transformación a la variable dependiente para que los residuos se ajusten a una distribución normal. Una opción es aplicar una transformación logarítmica a la variable dependiente, que en este caso es "Last year sales". Se procede con esta transformación.

# %%
# Si hay valores positivos, podemos aplicar log
y_log = np.log(df_analysis_multivariate_final['Last year sales'])

# Variable independiente
X = df_analysis_multivariate_final['Latent_sensing']
X_const = sm.add_constant(X)

# Ajustar modelo con Y transformada
modelo_log = sm.OLS(y_log, X_const).fit()

# Residuales del modelo logarítmico
residuos_log = modelo_log.resid

# Resumen del modelo
modelo_log.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Last year sales   R-squared:                       0.240
# Model:                            OLS   Adj. R-squared:                  0.211
# Method:                 Least Squares   F-statistic:                     8.204
# Date:                Sun, 15 Jun 2025   Prob (F-statistic):            0.00816
# Time:                        12:32:03   Log-Likelihood:                -52.033
# No. Observations:                  28   AIC:                             108.1
# Df Residuals:                      26   BIC:                             110.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              9.2909      0.304     30.530      0.000       8.665       9.916
# Latent_sensing     1.0938      0.382      2.864      0.008       0.309       1.879
# ==============================================================================
# Omnibus:                        0.569   Durbin-Watson:                   1.630
# Prob(Omnibus):                  0.753   Jarque-Bera (JB):                0.168
# Skew:                          -0.189   Prob(JB):                        0.919
# Kurtosis:                       3.041   Cond. No.                         1.25
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **I) Linealidad**

# %%
# Calcula el coeficiente de correlación de Pearson y el valor p
correlation_coefficient, p_value = stats.pearsonr(y_log, X)

# nivel de significancia (alpha)
alpha = 0.05

# Comparar el valor p con el nivel de significancia
if p_value < alpha:
    print("Hay evidencia de una relación lineal significativa (p < alpha)")
else:
    print("No hay evidencia de una relación lineal significativa (p >= alpha)")

print(f"Coeficiente de correlación de Pearson: {correlation_coefficient}")
# Out:
# Hay evidencia de una relación lineal significativa (p < alpha)
# Coeficiente de correlación de Pearson: 0.4897437599737421

# %% [markdown]
# Se evidencia una relación lineal positiva y significativa. Aunque el ajuiste del modelo es bajo.

# %% [markdown]
# **II) Independencia de errores**

# %%
errores = modelo_log.resid
errores_i_1 = errores[:-1]
errores_i = errores[1:]

plt.scatter(errores_i_1, errores_i,c='blue', marker='o',alpha=0.6)
plt.title('Gráfico de Dispersión de Error(i-1) vs Error(i)')
plt.xlabel('Error (i-1)')
plt.ylabel('Error (i)')
# Out:
# Text(0, 0.5, 'Error (i)')

# %% [markdown]
# En el gráfico anterior se evidencia que la dispersión sigue un patrón de esfericidad, por lo que se puede anticipar la no existencia de autocorrelación en los errores. Sin embargo, se procede a ejecutar una prueba estadística para confirmar lo anterior.
#
# Según lo reportado en la tabla anterior, el estadístico de la prueba de Durbin Watson tiene un valor de 1.630. Las pruebas de hipótesis de esta prueba son las siguientes:
#
# - **H0: cor(e_i,e_{i-1}==0** -> esto es NO hay autocorrelación entre los errores
# - **H1: cor(e_i,e_{i-1}!=0** -> esto es SÍ hay autocorrelación entre los erorres
#
# En este caso el estadístico DW está en el intervalo 1.5 y 2.5, por lo que no se debe rechazar la hipótesis nula de no autocorrelación, lo que permite **evidenciar la no autocorrelación entre los errores**.

# %% [markdown]
# **III) Homocedasticidad**

# %%
# Calcula los valores ajustados del modelo
valores_ajustados = modelo_log.fittedvalues

# Gráfico de dispersión de residuos vs valores ajustados
plt.scatter(valores_ajustados, errores, c='blue', marker='o', alpha=0.6)
plt.xlabel('Valores Ajustados')
plt.ylabel('Residuos')
plt.title('Gráfico de Residuos vs. Valores Ajustados')
plt.show()

# %%
# Suponiendo que 'modelo' es tu modelo de regresión ajustado
prueba_homocedasticidad = het_breuschpagan(errores, modelo_log.model.exog)

# La prueba devuelve varios valores, puedes ver el p-valor así:
p_valor = prueba_homocedasticidad[3]

print(f"P-valor asociado a la prueba Breusch Pagan: {p_valor}")
# Out:
# P-valor asociado a la prueba Breusch Pagan: 0.0009135457562928549

# %% [markdown]
# Las hipótesis asociadas a esta prueba son las siguientes:
#
# - **HO: e_i son homocedásticos** (homogeneidad de la varianza)
# - **H1: e_i no son homocedásticos** (heterogeneidad de la varianza)
#
# En este caso, el p-valor asociado a la prueba de Breusch-Pagan es menor a un nivel de significancia de 0.05, lo que lleva a rechazar la hipótesis nula de homocedasticidad. En este sentido, se concluye que **el modelo NO cumple con el supuesto de homocedasticidad en la varianza de los errores**.

# %% [markdown]
# **IV) Normalidad de los residuos**

# %%
sns.histplot(errores, kde=True)
plt.xlabel('Residuos')
plt.ylabel('Frecuencia')
plt.title('Histograma de Residuos')
plt.show()

# %%
# Crear el Q-Q plot
sm.qqplot(errores, line='s')  # 's' = línea de referencia con pendiente 1 (esperada si es normal)
plt.title("Q-Q Plot de los residuos")
plt.show()

# %%
# Aplicar la prueba de Shapiro-Wilk
stat, p = shapiro(errores)

# Mostrar el resultado
print("📊 Prueba de normalidad Shapiro-Wilk")
print(f"Estadístico W: {stat:.4f}")
print(f"Valor p: {p:.4f}")

# Interpretación
if p < 0.05:
    print("❌ Rechazamos H₀: los datos no siguen una distribución normal.")
else:
    print("✅ No se rechaza H₀: no hay evidencia de no normalidad.")
# Out:
# 📊 Prueba de normalidad Shapiro-Wilk
# Estadístico W: 0.9883
# Valor p: 0.9841
# ✅ No se rechaza H₀: no hay evidencia de no normalidad.

# %% [markdown]
# Este modelo con variable dependiente transformada (log) tiene un mejor ajuste que el modelo original OLS clásico, ya que los residuos parecen más homogéneos. En este caso, el modelo cumple con el supuesto de normalidad de los errores; sin embargo, no cumple el supuesto de homocedasticidad. En este caso, se correrá un modelo robusto que no asuma homocedasticidad.

# %%
# Transformación logarítmica de la variable dependiente
y_log = np.log(df_analysis_multivariate_final['Last year sales'])

# Variable independiente
X = df_analysis_multivariate_final['Latent_sensing']
X_const = sm.add_constant(X)

# Ajustar modelo OLS con errores estándar robustos (White)
modelo_robust_log = sm.OLS(y_log, X_const).fit(cov_type='HC1')

# Mostrar resumen del modelo
modelo_robust_log.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Last year sales   R-squared:                       0.240
# Model:                            OLS   Adj. R-squared:                  0.211
# Method:                 Least Squares   F-statistic:                     6.166
# Date:                Sun, 15 Jun 2025   Prob (F-statistic):             0.0198
# Time:                        12:32:04   Log-Likelihood:                -52.033
# No. Observations:                  28   AIC:                             108.1
# Df Residuals:                      26   BIC:                             110.7
# Df Model:                           1
# Covariance Type:                  HC1
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              9.2909      0.304     30.540      0.000       8.695       9.887
# Latent_sensing     1.0938      0.440      2.483      0.013       0.230       1.957
# ==============================================================================
# Omnibus:                        0.569   Durbin-Watson:                   1.630
# Prob(Omnibus):                  0.753   Jarque-Bera (JB):                0.168
# Skew:                          -0.189   Prob(JB):                        0.919
# Kurtosis:                       3.041   Cond. No.                         1.25
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """

# %% [markdown]
# **I) Linealidad**

# %%
# Calcula el coeficiente de correlación de Pearson y el valor p
correlation_coefficient, p_value = stats.pearsonr(y_log, X)

# nivel de significancia (alpha)
alpha = 0.05

# Comparar el valor p con el nivel de significancia
if p_value < alpha:
    print("Hay evidencia de una relación lineal significativa (p < alpha)")
else:
    print("No hay evidencia de una relación lineal significativa (p >= alpha)")

print(f"Coeficiente de correlación de Pearson: {correlation_coefficient}")
# Out:
# Hay evidencia de una relación lineal significativa (p < alpha)
# Coeficiente de correlación de Pearson: 0.4897437599737421

# %% [markdown]
# Se evidencia una relación lineal positiva y significativa. Aunque el ajuiste del modelo es bajo.

# %% [markdown]
# **II) Independencia de errores**

# %%
errores = modelo_robust_log.resid
errores_i_1 = errores[:-1]
errores_i = errores[1:]

plt.scatter(errores_i_1, errores_i,c='blue', marker='o',alpha=0.6)
plt.title('Gráfico de Dispersión de Error(i-1) vs Error(i)')
plt.xlabel('Error (i-1)')
plt.ylabel('Error (i)')
# Out:
# Text(0, 0.5, 'Error (i)')

# %% [markdown]
# En el gráfico anterior se evidencia que la dispersión sigue un patrón de esfericidad, por lo que se puede anticipar la no existencia de autocorrelación en los errores. Sin embargo, se procede a ejecutar una prueba estadística para confirmar lo anterior.
#
# Según lo reportado en la tabla anterior, el estadístico de la prueba de Durbin Watson tiene un valor de 1.630. Las pruebas de hipótesis de esta prueba son las siguientes:
#
# - **H0: cor(e_i,e_{i-1}==0** -> esto es NO hay autocorrelación entre los errores
# - **H1: cor(e_i,e_{i-1}!=0** -> esto es SÍ hay autocorrelación entre los erorres
#
# En este caso el estadístico DW está en el intervalo 1.5 y 2.5, por lo que no se debe rechazar la hipótesis nula de no autocorrelación, lo que permite **evidenciar la no autocorrelación entre los errores**.

# %% [markdown]
# **III) Homocedasticidad**

# %%
# Calcula los valores ajustados del modelo
valores_ajustados = modelo_robust_log.fittedvalues

# Gráfico de dispersión de residuos vs valores ajustados
plt.scatter(valores_ajustados, errores, c='blue', marker='o', alpha=0.6)
plt.xlabel('Valores Ajustados')
plt.ylabel('Residuos')
plt.title('Gráfico de Residuos vs. Valores Ajustados')
plt.show()

# %%
# Suponiendo que 'modelo' es tu modelo de regresión ajustado
prueba_homocedasticidad = het_breuschpagan(errores, modelo_robust_log.model.exog)

# La prueba devuelve varios valores, puedes ver el p-valor así:
p_valor = prueba_homocedasticidad[3]

print(f"P-valor asociado a la prueba Breusch Pagan: {p_valor}")
# Out:
# P-valor asociado a la prueba Breusch Pagan: 0.0009135457562928549

# %% [markdown]
# Las hipótesis asociadas a esta prueba son las siguientes:
#
# - **HO: e_i son homocedásticos** (homogeneidad de la varianza)
# - **H1: e_i no son homocedásticos** (heterogeneidad de la varianza)
#
# En este caso, el p-valor asociado a la prueba de Breusch-Pagan es menor a un nivel de significancia de 0.05, lo que lleva a aceptar la hipótesis nula de homocedasticidad. En este sentido, se concluye que **el modelo NO cumple con el supuesto de homocedasticidad en la varianza de los errores**.

# %% [markdown]
# **IV) Normalidad de los residuos**

# %%
sns.histplot(errores, kde=True)
plt.xlabel('Residuos')
plt.ylabel('Frecuencia')
plt.title('Histograma de Residuos')
plt.show()

# %%
# Crear el Q-Q plot
sm.qqplot(errores, line='s')  # 's' = línea de referencia con pendiente 1 (esperada si es normal)
plt.title("Q-Q Plot de los residuos")
plt.show()

# %%
# Aplicar la prueba de Shapiro-Wilk
stat, p = shapiro(errores)

# Mostrar el resultado
print("📊 Prueba de normalidad Shapiro-Wilk")
print(f"Estadístico W: {stat:.4f}")
print(f"Valor p: {p:.4f}")

# Interpretación
if p < 0.05:
    print("❌ Rechazamos H₀: los datos no siguen una distribución normal.")
else:
    print("✅ No se rechaza H₀: no hay evidencia de no normalidad.")
# Out:
# 📊 Prueba de normalidad Shapiro-Wilk
# Estadístico W: 0.9883
# Valor p: 0.9841
# ✅ No se rechaza H₀: no hay evidencia de no normalidad.

# %% [markdown]
# Este modelo no cumple homocedasticidad, sin embargo, al aplicar errores estándar robustos, se ajusta para corregir la heterocedasticidad. Esto permite que las inferencias estadísticas sean más confiables a pesar de la violación de la homocedasticidad.

# %% [markdown]
# ### **2.2.3 Industria de la empresa**

# %% [markdown]
# #### **Comprobación de normalidad de los datos**

# %%
# Aplicar Shapiro-Wilk a cada grupo
for group in df_analysis_multivariate_final['Industry'].unique():
    datos_grupo = df_analysis_multivariate_final[df_analysis_multivariate_final['Industry'] == group]['Latent_sensing']
    stat, p = shapiro(datos_grupo)
    print(f"\nGrupo: {group}")
    print(f"Estadístico Shapiro-Wilk: {stat:.4f}, p-valor: {p:.4f}")
    if p < 0.05:
        print("→ No es normal (rechaza H0)")
    else:
        print("→ Normal (no rechaza H0)")
# Out:
# Grupo: Manufacturing
# Estadístico Shapiro-Wilk: 0.9226, p-valor: 0.2399
# → Normal (no rechaza H0)
#
# Grupo: Services
# Estadístico Shapiro-Wilk: 0.9524, p-valor: 0.7355
# → Normal (no rechaza H0)
#
# Grupo: Commerce
# Estadístico Shapiro-Wilk: 0.6173, p-valor: 0.0007
# → No es normal (rechaza H0)

# %% [markdown]
# No cumple normalidad, hay que aplicar Kruskal-Wallis como prueba de hipótesis, y, si esta prueba comprueba que hay al menos una diferencia estadísticamente significativa entre las medias del índice de sensing de un par de grupos de Industry, se aplicaría prueba de Dunn como post-hoc.

# %%
# Agrupar los valores de Indice_Sensing por categoría en Industry
groups = df_analysis_multivariate_final.groupby('Industry')['Latent_sensing'].apply(list)

# Aplicar la prueba de Kruskal-Wallis
stat, p_value = kruskal(*groups)

print(f'Estadístico H: {stat:.4f}')
print(f'Valor p: {p_value:.4f}')

# Interpretación del resultado
if p_value < 0.05:
    print("Hay diferencias estadísticamente significativas en Indice_Sensing entre al menos dos industrias.")
else:
    print("No hay diferencias estadísticamente significativas en Indice_Sensing entre las industrias.")
# Out:
# Estadístico H: 0.5757
# Valor p: 0.7499
# No hay diferencias estadísticamente significativas en Indice_Sensing entre las industrias.

# %%
fig_boxplot = plt.figure(figsize=(10,5)) 
ax = fig_boxplot.add_axes([0,0,1,1])

resumen=df_analysis_multivariate_final.groupby(by=["Industry"])["Latent_sensing"].describe()

ax=sns.boxplot(x=df_analysis_multivariate_final["Industry"], y=df_analysis_multivariate_final["Latent_sensing"],order=resumen.sort_values(by='50%', ascending=False).index)
plt.ylabel('')   
plt.xlabel('')           
plt.show()

# %% [markdown]
# No hay diferencias estadísticamente significativas en los valores del Indice_Sensing entre los distintos grupos de la variable Industry. No será necesaria prueba post-hoc.

# %% [markdown]
# ### **2.2.4 Sectores de la empresa**

# %% [markdown]
# No se pueden aplicar pruebas estadísticas para revisar diferencias entre grupos para esta variable dado que para algunos sectores tenemos menos de 3 observaciones y es necesario tener al menos 3 observaciones para poder aplicar la prueba de Shapiro-Wilk, con el propósito de revisar normalidad.

# %% [markdown]
# ### **2.2.5 Ubicación geográfica de la empresa**

# %% [markdown]
# #### **Comprobación de normalidad de los datos**

# %%
from scipy.stats import shapiro

# Ejecutar la prueba de Shapiro-Wilk por grupo de 'Sector'
resultados_shapiro = []

for group in df_analysis_multivariate_final['Geographic reach location'].unique():
    datos_grupo = df_analysis_multivariate_final[df_analysis_multivariate_final['Geographic reach location'] == group]['Latent_sensing']
    
    # Evitar aplicar la prueba si hay menos de 3 observaciones (Shapiro requiere al menos 3)
    if len(datos_grupo) < 3:
        resultados_shapiro.append({
            "Geographic reach location": group,
            "N": len(datos_grupo),
            "Estadístico": None,
            "p-valor": None,
            "Normalidad": "No aplica (<3 observaciones)"
        })
        continue
    
    stat, p = shapiro(datos_grupo)
    normalidad = "Normal (no rechaza H0)" if p >= 0.05 else "No es normal (rechaza H0)"
    resultados_shapiro.append({
        "Geographic reach location": group,
        "N": len(datos_grupo),
        "Estadístico": stat,
        "p-valor": p,
        "Normalidad": normalidad
    })

import pandas as pd
df_shapiro = pd.DataFrame(resultados_shapiro)
df_shapiro
# Out:
#   Geographic reach location   N  Estadístico   p-valor  \
# 0                  Regional   2          NaN       NaN
# 1                  National   9     0.845919  0.067180
# 2                     Local  14     0.917688  0.203654
# 3             International   3     0.833903  0.198298
#
#                      Normalidad
# 0  No aplica (<3 observaciones)
# 1        Normal (no rechaza H0)
# 2        Normal (no rechaza H0)
# 3        Normal (no rechaza H0)

# %% [markdown]
# El número de empresas regional es apenas 2, por lo que no se puede comprobar normalidad en ese grupo. Por tanto, se excluye del análisis.

# %%
# Quitar registros con location regional
df_analysis_multivariate_final_location=df_analysis_multivariate_final[df_analysis_multivariate_final['Geographic reach location'] != 'Regional']

# %%
#### **Comprobación de homogeneidad de varianzas**

# Agrupar los datos de 'Indice_Sensing' por ubicación geográfica
grupos = df_analysis_multivariate_final_location.groupby('Geographic reach location')['Latent_sensing'].apply(list)

# Aplicar la prueba de Levene
stat_levene, p_levene = levene(*grupos)

# Mostrar resultados
stat_levene, p_levene

# Imprimir el resultado
print("📊 Resultado de la prueba de Levene (homogeneidad de varianzas)")
print("---------------------------------------------------------------")
print(f"Estadístico de Levene: {stat_levene:.4f}")
print(f"Valor p: {p_levene:.4f}")

if p_levene < 0.05:
    print("→ Se rechaza la hipótesis nula: hay evidencia de que las varianzas no son iguales.")
else:
    print("→ No se rechaza la hipótesis nula: no hay evidencia de que las varianzas sean diferentes.")
# Out:
# 📊 Resultado de la prueba de Levene (homogeneidad de varianzas)
# ---------------------------------------------------------------
# Estadístico de Levene: 1.0330
# Valor p: 0.3719
# → No se rechaza la hipótesis nula: no hay evidencia de que las varianzas sean diferentes.

# %% [markdown]
# Se comprueba homogeneidad de varianzas para aplicar ANOVA.

# %%
# 1. Classical ANOVA
groups = df_analysis_multivariate_final.groupby('Geographic reach location')['Latent_sensing'].apply(list)
f_stat, p_value = f_oneway(*groups)

print("\nClassical ANOVA results:")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# 2. Check if significant
if p_value < 0.05:
    print("\nANOVA is significant (p < 0.05). Applying Tukey HSD test...")

    # 3. Tukey HSD post-hoc test
    tukey = pairwise_tukeyhsd(endog=df_analysis_multivariate_final['Latent_sensing'],
                              groups=df_analysis_multivariate_final['Geographic reach location'],
                              alpha=0.05)
    tukey_summary = pd.DataFrame(data=tukey.summary().data[1:], columns=tukey.summary().data[0])
    tukey_summary['Interpretation'] = tukey_summary['p-adj'].apply(lambda x: 'Different' if x < 0.05 else 'Equal')

    # 4. Compute medians by group and sort
    medians = df_analysis_multivariate_final.groupby('Geographic reach location')['Latent_sensing'].median().reset_index()
    category_order = medians.sort_values('Latent_sensing', ascending=False)['Geographic reach location'].tolist()

    # 5. Create figure (boxplot + table)
    fig, ax = plt.subplots(2, 1, figsize=(8, 8), gridspec_kw={'height_ratios': [3, 1]})

    sns.boxplot(x='Geographic reach location', y='Latent_sensing', data=df_analysis_multivariate_final,
                ax=ax[0], palette="Set2", order=category_order)
    ax[0].set_title("Sensing by Geographic reach location")
    ax[0].set_xlabel("Geographic reach location")
    ax[0].set_ylabel("Latent Variable (Sensing)")

    # Annotate medians
    for i, row in medians.iterrows():
        idx = category_order.index(row['Geographic reach location'])
        offset = 0.05
        ax[0].text(idx, row['Latent_sensing'] + offset, 
                   f"{row['Latent_sensing']:.2f}", 
                   ha='center', va='bottom', fontweight='bold', color='black',
                   bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.05', linewidth=0.3))

    # 6. Add table below the plot
    table = tukey_summary[['group1', 'group2', 'Interpretation']]
    ax[1].axis('off')
    table_text = table.values.tolist()
    column_labels = ['Group 1', 'Group 2', 'Comparison']
    ax[1].table(cellText=table_text, colLabels=column_labels, loc='center', cellLoc='center')

    plt.tight_layout()
    plt.show()

else:
    print("\nANOVA is not significant (p ≥ 0.05). Tukey HSD test and plot will not be generated.")
# Out:
# Classical ANOVA results:
# F-statistic: 0.6970
# P-value: 0.5630
#
# ANOVA is not significant (p ≥ 0.05). Tukey HSD test and plot will not be generated.

# %% [markdown]
# No hay evidencia estadísticamente significativa de que las medias del Indice_Sensing difieran entre las ubicaciones geográficas (National, Local, International).

# %%
fig_boxplot = plt.figure(figsize=(10,5)) 
ax = fig_boxplot.add_axes([0,0,1,1])

resumen=df_analysis_multivariate_final_location.groupby(by=["Geographic reach location"])["Latent_sensing"].describe()

ax=sns.boxplot(x=df_analysis_multivariate_final_location["Geographic reach location"], y=df_analysis_multivariate_final_location["Latent_sensing"],order=resumen.sort_values(by='50%', ascending=False).index)
plt.ylabel('')   
plt.xlabel('')           
plt.show()

# %% [markdown]
# ### **2.2.6 Edad de la empresa**

# %%
# Pearson correlation coefficient and p-value calculation
r, p_value = pearsonr(df_analysis_multivariate_final['Latent_sensing'], df_analysis_multivariate_final['Age of company'])

# Results
print(f"Pearson correlation coefficient: r = {r:.4f}")
print(f"p-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("There is significant evidence of a linear correlation between 'Latent_sensing' and 'Age of company'.")
else:
    print("No significant evidence of a linear correlation was found between 'Latent_sensing' and 'Age of company'.")

# Visualization
plt.figure(figsize=(8, 6))
sns.regplot(data=df_analysis_multivariate_final, x='Age of company', y='Latent_sensing', ci=95, line_kws={'color': 'red'})
plt.title(f"Correlation between Latent Variable (Sensing) and Last Year Sales\nr = {r:.2f}, p = {p_value:.4f}")
plt.xlabel("Age of company")
plt.ylabel("Latent variable (Sensing)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Pearson correlation coefficient: r = 0.0446
# p-value: 0.8216
# No significant evidence of a linear correlation was found between 'Latent_sensing' and 'Age of company'.

# %%
# Nivel de significancia
alpha = 0.05

# Spearman
rho_spearman, p_spearman = spearmanr(df_analysis_multivariate_final['Latent_sensing'], df_analysis_multivariate_final['Age of company'])
print("=== Correlación de Spearman ===")
print(f"Coeficiente rho: {rho_spearman:.4f}")
print(f"Valor p: {p_spearman:.4f}")
if p_spearman < alpha:
    print("→ Existe una relación monótona significativa entre las variables (se rechaza H₀).")
else:
    print("→ No existe una relación monótona significativa entre las variables (no se rechaza H₀).")

print("\n")

# Kendall
tau_kendall, p_kendall = kendalltau(df_analysis_multivariate_final['Latent_sensing'], df_analysis_multivariate_final['Age of company'])
print("=== Correlación de Kendall ===")
print(f"Coeficiente tau: {tau_kendall:.4f}")
print(f"Valor p: {p_kendall:.4f}")
if p_kendall < alpha:
    print("→ Existe una relación significativa según Kendall (se rechaza H₀).")
else:
    print("→ No existe una relación significativa según Kendall (no se rechaza H₀).")
# Out:
# === Correlación de Spearman ===
# Coeficiente rho: 0.2078
# Valor p: 0.2888
# → No existe una relación monótona significativa entre las variables (no se rechaza H₀).
#
#
# === Correlación de Kendall ===
# Coeficiente tau: 0.1687
# Valor p: 0.2123
# → No existe una relación significativa según Kendall (no se rechaza H₀).

# %% [markdown]
# No se considera necesario avanzar hacia la aplicaciòn de una regresión lineal simple, ya que la prueba de correlación de Pearson ya ha indicado que no hay evidencia de una relación lineal significativa entre las variables 'Latent_sensing' y 'Age of company'.

# %% [markdown]
# ### **2.2.8 R&D Expenditure**

# %%
# Pearson correlation coefficient and p-value calculation
r, p_value = pearsonr(df_analysis_multivariate_final['Latent_sensing'], df_analysis_multivariate_final['R&D expenditure'])

# Results
print(f"Pearson correlation coefficient: r = {r:.4f}")
print(f"p-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("There is significant evidence of a linear correlation between 'Latent_sensing' and 'R&D expenditure'.")
else:
    print("No significant evidence of a linear correlation was found between 'Latent_sensing' and 'R&D expenditure'.")

# Visualization
plt.figure(figsize=(8, 6))
sns.regplot(data=df_analysis_multivariate_final, x='R&D expenditure', y='Latent_sensing', ci=95, line_kws={'color': 'red'})
plt.title(f"Correlation between Latent Variable (Sensing) and Last Year Sales\nr = {r:.2f}, p = {p_value:.4f}")
plt.xlabel("R&D expenditure")
plt.ylabel("Latent variable (Sensing)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Pearson correlation coefficient: r = -0.2065
# p-value: 0.2918
# No significant evidence of a linear correlation was found between 'Latent_sensing' and 'R&D expenditure'.

# %%
# Nivel de significancia
alpha = 0.05

# Spearman
rho_spearman, p_spearman = spearmanr(df_analysis_multivariate_final['Latent_sensing'], df_analysis_multivariate_final['R&D expenditure'])
print("=== Correlación de Spearman ===")
print(f"Coeficiente rho: {rho_spearman:.4f}")
print(f"Valor p: {p_spearman:.4f}")
if p_spearman < alpha:
    print("→ Existe una relación monótona significativa entre las variables (se rechaza H₀).")
else:
    print("→ No existe una relación monótona significativa entre las variables (no se rechaza H₀).")

print("\n")

# Kendall
tau_kendall, p_kendall = kendalltau(df_analysis_multivariate_final['Latent_sensing'], df_analysis_multivariate_final['R&D expenditure'])
print("=== Correlación de Kendall ===")
print(f"Coeficiente tau: {tau_kendall:.4f}")
print(f"Valor p: {p_kendall:.4f}")
if p_kendall < alpha:
    print("→ Existe una relación significativa según Kendall (se rechaza H₀).")
else:
    print("→ No existe una relación significativa según Kendall (no se rechaza H₀).")
# Out:
# === Correlación de Spearman ===
# Coeficiente rho: 0.1454
# Valor p: 0.4604
# → No existe una relación monótona significativa entre las variables (no se rechaza H₀).
#
#
# === Correlación de Kendall ===
# Coeficiente tau: 0.1294
# Valor p: 0.3468
# → No existe una relación significativa según Kendall (no se rechaza H₀).

# %% [markdown]
# ### **2.2.9 Number of patents innovations**

# %%
df_analysis_multivariate_final
# Out:
#    Company  Latent_sensing  Latent_seizing  Latent_transformation  \
# 0      C01        1.599147        1.305140               1.829091
# 1      C02        0.495534        0.435867               0.795335
# 2      C03        1.566232        1.703583               1.637924
# 3      C04       -0.467213       -0.401244              -0.331791
# 4      C05        0.318504        0.533603               0.398109
# 5      C06       -1.502069       -1.351313              -1.699216
# 6      C07        0.241241        0.006293              -0.390087
# 7      C08       -0.200324       -0.130438               0.592535
# 8      C09        2.190476        2.629447               2.181530
# 9      C10        0.501075       -0.009984               0.578918
# 10     C11       -0.042040       -0.580320              -0.626904
# 11     C12       -0.322200       -0.269024              -0.545377
# 12     C13       -0.221294       -0.300631              -0.125929
# 13     C14       -0.396047       -0.904418              -0.450626
# 14     C15       -0.246015       -0.313822               0.256988
# 15     C16       -0.016718        0.071475              -0.164969
# 16     C17       -0.807466       -0.273281              -0.790574
# 17     C18       -0.419506       -0.099065              -0.590558
# 18     C19       -1.001584       -0.821911              -1.429304
# 19     C20        0.818837        0.622122               0.643801
# 20     C21        0.019073        0.136457               0.214117
# 21     C22        0.295721        0.274236              -0.073095
# 22     C23       -0.436500       -0.090359              -0.236842
# 23     C24       -1.217122       -0.201687              -0.239376
# 24     C25       -0.296984       -0.293261              -0.019235
# 25     C26       -0.078279        0.045598              -0.359533
# 26     C27       -0.222954       -0.092214              -0.648398
# 27     C28       -0.160187       -1.774918              -0.420191
#
#     Latent_sensing_Z  Latent_seizing_Z  Latent_transformation_Z Company size  \
# 0           1.599663          1.310607                 1.831444          Big
# 1           0.495907          0.441121                 0.796633          Big
# 2           1.566743          1.709148                 1.640082          Big
# 3          -0.466963         -0.396196                -0.331641       Medium
# 4           0.318855          0.538881                 0.399003       Medium
# 5          -1.501954         -1.346499                -1.700460       Medium
# 6           0.241581          0.011441                -0.389997       Medium
# 7          -0.200041         -0.125323                 0.593628        Small
# 8           2.191067          2.635239                 2.184242          Big
# 9           0.501449         -0.004840                 0.579997       Medium
# 10         -0.041736         -0.575316                -0.627055        Small
# 11         -0.321933         -0.263944                -0.545444       Medium
# 12         -0.221013         -0.295559                -0.125569       Medium
# 13         -0.395789         -0.899494                -0.450597       Medium
# 14         -0.245737         -0.308753                 0.257738        Small
# 15         -0.016411          0.076639                -0.164649        Small
# 16         -0.807260         -0.268201                -0.790891        Micro
# 17         -0.419251         -0.093943                -0.590672        Micro
# 18         -1.001404         -0.816966                -1.430272       Medium
# 19          0.819252          0.627421                 0.644945       Medium
# 20          0.019385          0.141637                 0.214824       Medium
# 21          0.296069          0.279450                -0.072682       Medium
# 22         -0.436247         -0.085234                -0.236595        Small
# 23         -1.216969         -0.196590                -0.239131        Micro
# 24         -0.296713         -0.288187                -0.018767       Medium
# 25         -0.077980          0.050756                -0.359411       Medium
# 26         -0.222673         -0.087091                -0.648571        Micro
# 27         -0.159899         -1.770207                -0.420131       Medium
#
#          Industry                    Sector  Last year sales  Age of company  \
# 0   Manufacturing                   Fashion     85000.000000              29
# 1        Services        Food and Beverages     94500.000000               6
# 2   Manufacturing                   Fashion    110000.000000               8
# 3        Services   Transport and Logistics     13450.000000              23
# 4        Services                Technology     19250.000000              25
# 5   Manufacturing              Construction     71200.000000              30
# 6   Manufacturing              Construction     64000.000000              40
# 7   Manufacturing                   Fashion      3270.000000              12
# 8        Commerce             Ferroelectric    110000.000000              24
# 9   Manufacturing                   Fashion     14760.000000              21
# 10       Commerce                  Textiles     14780.000000              20
# 11  Manufacturing                   Fashion     55000.000000              16
# 12       Commerce                    Sports     19230.000000              27
# 13  Manufacturing                   Fashion      8325.000000              12
# 14       Commerce                Technology      2550.000000               5
# 15       Services                Automotive      1560.000000               5
# 16  Manufacturing                   Fashion       120.000000               5
# 17       Commerce  Beauty and Personal Care      1450.000000               6
# 18  Manufacturing                 Packaging     36250.000000              46
# 19       Services        Food and Beverages     12450.000000              18
# 20  Manufacturing              Construction     15943.979000              47
# 21       Services                 Education      5786.273819              21
# 22  Manufacturing                   Fashion      9200.000000              11
# 23       Services                 Education       185.000000               6
# 24  Manufacturing              Construction     26242.449862              16
# 25  Manufacturing                    Energy      5000.000000              33
# 26       Services       Process Improvement       850.000000               7
# 27       Commerce                Stationery     24000.000000              17
#
#    Geographic reach location  R&D expenditure  New products sales  \
# 0                   Regional     2.000000e-02        1.785000e+10
# 1                   National     1.037000e+09        2.835000e+09
# 2                      Local     0.000000e+00        1.320000e+10
# 3              International     1.200000e+09        4.800000e+09
# 4                   National     9.625000e+08        3.850000e+09
# 5                   National     1.424000e+09        1.780000e+10
# 6                   National     1.000000e+07        3.620077e+10
# 7                   National     9.810000e+07        3.270000e+08
# 8              International     1.200000e+08        2.600000e+08
# 9                      Local     1.000000e+08        1.476000e+09
# 10                     Local     0.000000e+00        4.434000e+09
# 11                     Local     0.000000e+00        3.300000e+09
# 12                     Local     9.615000e+08        5.769000e+09
# 13                     Local     0.000000e+00        5.000000e+08
# 14                  Regional     1.200000e+07        7.650000e+07
# 15                     Local     1.092000e+08        0.000000e+00
# 16             International     3.500000e+06        7.200000e+07
# 17                  National     0.000000e+00        0.000000e+00
# 18                     Local     0.000000e+00        4.531250e+09
# 19                     Local     1.245000e+08        6.225000e+08
# 20                  National     8.500000e+07        0.000000e+00
# 21                  National     3.000000e+07        1.000000e+08
# 22                     Local     4.600000e+08        2.760000e+09
# 23                     Local     0.000000e+00        3.500000e+07
# 24                  National     9.000000e+07        3.730000e+09
# 25                     Local     1.000000e+08        1.300000e+08
# 26                     Local     6.000000e+07        2.500000e+06
# 27                     Local     0.000000e+00        5.760000e+09
#
#     Number of patents innovations  Annual growth
# 0                              12           0.18
# 1                               8           0.24
# 2                               4           0.10
# 3                               6           0.15
# 4                               4           0.08
# 5                               4           0.26
# 6                               3           0.20
# 7                               3           0.12
# 8                               2           0.14
# 9                               3          -0.03
# 10                              4           0.03
# 11                              9           0.23
# 12                              3           0.15
# 13                              1          -0.05
# 14                              1           0.05
# 15                              1           0.40
# 16                              3           0.05
# 17                              0           0.20
# 18                              5           0.05
# 19                              2           0.15
# 20                              2           0.20
# 21                              1           0.10
# 22                              0           0.12
# 23                              2           0.08
# 24                              3           0.05
# 25                              2           0.01
# 26                              2           0.20
# 27                              2           0.04

# %%
# Specific variables
df_plot = df_analysis_multivariate_final.copy()
y_var = "Latent_sensing"
x_var = "Number of patents innovations"

# Fit linear regression model
X = df_plot[[x_var]]  # design matrix (2D)
y = df_plot[y_var]
model = LinearRegression().fit(X, y)

# Predict values and compute R²
y_pred = model.predict(X)
r2 = r2_score(y, y_pred)

# Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x=x_var, y=y_var, data=df_plot, color='darkgreen', s=60)
sns.lineplot(x=df_plot[x_var], y=y_pred, color='red', linewidth=2, label='Linear regression')

# Customize labels and title
plt.title("Relationship between Latent Variable (Sensing) and Number of patent innovations", fontsize=14)
plt.xlabel("Latent Variable (Sensing)")
plt.ylabel("Number of patent innovations")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_promedio_empresa_corr=df_analysis_multivariate_final.copy()

# Cammbio de nombre de Indice_Sensing
df_promedio_empresa_corr.rename(columns={'Indice_Sensing': 'Latent_sensing'}, inplace=True)

# Elegir las columnas que se desean analizar
df_promedio_empresa_corr = df_promedio_empresa_corr[["Latent_sensing","Number of patents innovations"]]

categorical_features=identify_nominal_columns(df_promedio_empresa_corr)
continuous_features=identify_numeric_columns(df_promedio_empresa_corr)

# %%
from dython.nominal import associations
target_correlation= associations(df_promedio_empresa_corr, display_rows=["Latent_sensing"], filename= 'target_correlation.png', figsize=(20,5))
# Out:
# C:\Users\monte\AppData\Roaming\Python\Python311\site-packages\dython\nominal.py:736: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   inf_nan.loc[columns[i], columns[j]] = _inf_nan_str(ij)
# C:\Users\monte\AppData\Roaming\Python\Python311\site-packages\dython\nominal.py:737: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   inf_nan.loc[columns[j], columns[i]] = _inf_nan_str(ji)

# %%
from scipy.stats import spearmanr

# Supongamos que tienes dos variables en un DataFrame
x = df_analysis_multivariate_final['Latent_sensing']
y = df_analysis_multivariate_final['R&D expenditure']

# Calcular la correlación de Spearman
coef, p_value = spearmanr(x, y)

print(f"Coeficiente de Spearman: {coef:.4f}")
print(f"Valor p: {p_value:.4f}")

# Interpretación
if p_value < 0.05:
    print("✔️ La correlación es estadísticamente significativa.")
else:
    print("❌ No hay evidencia de una correlación significativa.")
# Out:
# Coeficiente de Spearman: 0.1454
# Valor p: 0.4604
# ❌ No hay evidencia de una correlación significativa.

# %%
from scipy.stats import kendalltau

# Supón que tienes tus dos variables en un DataFrame
x = df_analysis_multivariate_final['Latent_sensing']
y = df_analysis_multivariate_final['R&D expenditure']

# Calcular la correlación de Kendall
coef, p_value = kendalltau(x, y)

print(f"Coeficiente de Kendall τ: {coef:.4f}")
print(f"Valor p: {p_value:.4f}")

# Interpretación
if p_value < 0.05:
    print("✔️ La correlación es estadísticamente significativa.")
else:
    print("❌ No hay evidencia de una correlación significativa.")
# Out:
# Coeficiente de Kendall τ: 0.1294
# Valor p: 0.3468
# ❌ No hay evidencia de una correlación significativa.

# %%
df_promedio_empresa_reg_lineal = df_analysis_multivariate_final[["Latent_sensing","Number of patents innovations"]]

x=df_promedio_empresa_reg_lineal.drop(["Latent_sensing"], axis=1)
y=df_promedio_empresa_reg_lineal["Latent_sensing"]
X = sm.add_constant(x) 
model = sm.OLS(y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Latent_sensing   R-squared:                       0.054
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     1.493
# Date:               dom, 15 jun. 2025   Prob (F-statistic):              0.233
# Time:                        12:38:22   Log-Likelihood:                -32.593
# No. Observations:                  28   AIC:                             69.19
# Df Residuals:                      26   BIC:                             71.85
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                            -0.2300      0.242     -0.951      0.350      -0.727       0.267
# Number of patents innovations     0.0699      0.057      1.222      0.233      -0.048       0.187
# ==============================================================================
# Omnibus:                        6.384   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                4.649
# Skew:                           0.734   Prob(JB):                       0.0978
# Kurtosis:                       4.353   Cond. No.                         6.95
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **I) Linealidad**

# %%
# Extrae las columnas Y y X del DataFrame
Y = df_analysis_multivariate_final['Number of patents innovations']
X = df_analysis_multivariate_final['Latent_sensing']

# %%
# Calcula el coeficiente de correlación de Pearson y el valor p
correlation_coefficient, p_value = stats.pearsonr(Y, X)

# nivel de significancia (alpha)
alpha = 0.05

# Comparar el valor p con el nivel de significancia
if p_value < alpha:
    print("Hay evidencia de una relación lineal significativa (p < alpha)")
else:
    print("No hay evidencia de una relación lineal significativa (p >= alpha)")

print(f"Coeficiente de correlación de Pearson: {correlation_coefficient}")
# Out:
# No hay evidencia de una relación lineal significativa (p >= alpha)
# Coeficiente de correlación de Pearson: 0.23306139742371004

# %% [markdown]
# Se evidencia una relación lineal positiva y significativa. Aunque el ajuiste del modelo es bajo.

# %% [markdown]
# **II) Independencia de errores**

# %%
errores = result.resid
errores_i_1 = errores[:-1]
errores_i = errores[1:]

plt.scatter(errores_i_1, errores_i,c='blue', marker='o',alpha=0.6)
plt.title('Gráfico de Dispersión de Error(i-1) vs Error(i)')
plt.xlabel('Error (i-1)')
plt.ylabel('Error (i)')
# Out:
# Text(0, 0.5, 'Error (i)')

# %% [markdown]
# En el gráfico anterior se evidencia que la dispersión sigue un patrón de esfericidad, por lo que se puede anticipar la no existencia de autocorrelación en los errores. Sin embargo, se procede a ejecutar una prueba estadística para confirmar lo anterior.
#
# Según lo reportado en la tabla anterior, el estadístico de la prueba de Durbin Watson tiene un valor de 2.036. Las pruebas de hipótesis de esta prueba son las siguientes:
#
# - **H0: cor(e_i,e_{i-1}==0** -> esto es NO hay autocorrelación entre los errores
# - **H1: cor(e_i,e_{i-1}!=0** -> esto es SÍ hay autocorrelación entre los erorres
#
# En este caso el estadístico DW está en el intervalo 1.5 y 2.5, por lo que no se debe rechazar la hipótesis nula de no autocorrelación, lo que permite **evidenciar la no autocorrelación entre los errores**.

# %% [markdown]
# **III) Homocedasticidad**

# %%
# Calcula los valores ajustados del modelo
valores_ajustados = result.fittedvalues

# Gráfico de dispersión de residuos vs valores ajustados
plt.scatter(valores_ajustados, errores, c='blue', marker='o', alpha=0.6)
plt.xlabel('Valores Ajustados')
plt.ylabel('Residuos')
plt.title('Gráfico de Residuos vs. Valores Ajustados')
plt.show()

# %%
# Suponiendo que 'modelo' es tu modelo de regresión ajustado
prueba_homocedasticidad = het_breuschpagan(errores, result.model.exog)

# La prueba devuelve varios valores, puedes ver el p-valor así:
p_valor = prueba_homocedasticidad[3]

print(f"P-valor asociado a la prueba Breusch Pagan: {p_valor}")
# Out:
# P-valor asociado a la prueba Breusch Pagan: 0.6326388530219549

# %% [markdown]
# Las hipótesis asociadas a esta prueba son las siguientes:
#
# - **HO: e_i son homocedásticos** (homogeneidad de la varianza)
# - **H1: e_i no son homocedásticos** (heterogeneidad de la varianza)
#
# En este caso, el p-valor asociado a la prueba de Breusch-Pagan es mayor a un nivel de significancia de 0.05, lo que lleva a aceptar la hipótesis nula de homocedasticidad. En este sentido, se concluye que **el modelo cumple con el supuesto de homocedasticidad en la varianza de los errores**.

# %% [markdown]
# **IV) Normalidad de los residuos**

# %%
sns.histplot(errores, kde=True)
plt.xlabel('Residuos')
plt.ylabel('Frecuencia')
plt.title('Histograma de Residuos')
plt.show()

# %%
# Crear el Q-Q plot
sm.qqplot(errores, line='s')  # 's' = línea de referencia con pendiente 1 (esperada si es normal)
plt.title("Q-Q Plot de los residuos")
plt.show()

# %%
# Aplicar la prueba de Shapiro-Wilk
stat, p = shapiro(errores)

# Mostrar el resultado
print("📊 Prueba de normalidad Shapiro-Wilk")
print(f"Estadístico W: {stat:.4f}")
print(f"Valor p: {p:.4f}")

# Interpretación
if p < 0.05:
    print("❌ Rechazamos H₀: los datos no siguen una distribución normal.")
else:
    print("✅ No se rechaza H₀: no hay evidencia de no normalidad.")
# Out:
# 📊 Prueba de normalidad Shapiro-Wilk
# Estadístico W: 0.9387
# Valor p: 0.1027
# ✅ No se rechaza H₀: no hay evidencia de no normalidad.

# %%
# Preparar variables para el análisis
X = df_analysis_multivariate_final['Latent_sensing']
y = df_analysis_multivariate_final['Last year sales']
X_const = sm.add_constant(X)

# Ajustar modelo OLS
modelo_ols = sm.OLS(y, X_const).fit()

# Ajustar modelo robusto (RLM)
modelo_rlm = sm.RLM(y, X_const, M=sm.robust.norms.HuberT()).fit()

# Bootstrap para el coeficiente de 'Latent_sensing'
n_iterations = 1000
coef_bootstrap = []

for _ in range(n_iterations):
    sample = resample(df_analysis_multivariate_final)
    X_sample = sm.add_constant(sample['Latent_sensing'])
    y_sample = sample['Last year sales']
    model_sample = sm.OLS(y_sample, X_sample).fit()
    coef_bootstrap.append(model_sample.params['Latent_sensing'])

# Calcular intervalo de confianza bootstrap (percentil)
ci_lower = np.percentile(coef_bootstrap, 2.5)
ci_upper = np.percentile(coef_bootstrap, 97.5)
coef_mean = np.mean(coef_bootstrap)

# Resumen de resultados
resultados = {
    'Modelo': ['OLS clásico', 'Regresión robusta (RLM)', 'Bootstrap OLS'],
    'Coeficiente': [
        modelo_ols.params['Latent_sensing'],
        modelo_rlm.params['Latent_sensing'],
        coef_mean
    ],
    'IC 95% Inferior': [
        modelo_ols.conf_int().loc['Latent_sensing', 0],
        np.nan,
        ci_lower
    ],
    'IC 95% Superior': [
        modelo_ols.conf_int().loc['Latent_sensing', 1],
        np.nan,
        ci_upper
    ],
    'Valor p': [
        modelo_ols.pvalues['Latent_sensing'],
        modelo_rlm.pvalues['Latent_sensing'],
        np.nan
    ]
}

df_resultados = pd.DataFrame(resultados)
df_resultados
# Out:
#                     Modelo   Coeficiente  IC 95% Inferior  IC 95% Superior  \
# 0              OLS clásico  24940.904483     10828.164248     39053.644718
# 1  Regresión robusta (RLM)  28053.419699              NaN              NaN
# 2            Bootstrap OLS  24812.256683      2423.413402     41233.376593
#
#     Valor p
# 0  0.001209
# 1  0.000020
# 2       NaN

# %% [markdown]
# ## **2.3 Análisis bivariados - Índice Seizing**

# %% [markdown]
# ### **2.3.1 Tamaño de la empresa**

# %% [markdown]
# #### **Comprobación de normalidad de los datos**

# %%
# Aplicar Shapiro-Wilk a cada grupo
for group in df_analysis_multivariate_final['Company size'].unique():
    datos_grupo = df_analysis_multivariate_final[df_analysis_multivariate_final['Company size'] == group]['Latent_seizing']
    stat, p = shapiro(datos_grupo)
    print(f"\nGrupo: {group}")
    print(f"Estadístico Shapiro-Wilk: {stat:.4f}, p-valor: {p:.4f}")
    if p < 0.05:
        print("→ No es normal (rechaza H0)")
    else:
        print("→ Normal (no rechaza H0)")
# Out:
# Grupo: Big
# Estadístico Shapiro-Wilk: 0.9963, p-valor: 0.9872
# → Normal (no rechaza H0)
#
# Grupo: Medium
# Estadístico Shapiro-Wilk: 0.9396, p-valor: 0.3776
# → Normal (no rechaza H0)
#
# Grupo: Small
# Estadístico Shapiro-Wilk: 0.9577, p-valor: 0.7922
# → Normal (no rechaza H0)
#
# Grupo: Micro
# Estadístico Shapiro-Wilk: 0.8819, p-valor: 0.3469
# → Normal (no rechaza H0)

# %% [markdown]
# #### **Comprobación de homogeneidad de varianzas**

# %%
# Agrupar los datos por grupo
grupos = df_analysis_multivariate_final['Company size'].unique()
datos_por_grupo = [df_analysis_multivariate_final[df_analysis_multivariate_final['Company size'] == g]['Latent_seizing'] for g in grupos]

# Aplicar prueba de Levene
stat, p = levene(*datos_por_grupo)
print(f"Estadístico Levene: {stat:.4f}, p-valor: {p:.4f}")

if p < 0.05:
    print("→ Varianzas diferentes (rechaza H0)")
else:
    print("→ Varianzas iguales (no rechaza H0)")
# Out:
# Estadístico Levene: 2.4280, p-valor: 0.0901
# → Varianzas iguales (no rechaza H0)

# %% [markdown]
# #### **Aplicación de pruebas estadísticas para revisión de diferencias entre medianas**

# %%
# 1. Classical ANOVA
groups = df_analysis_multivariate_final.groupby('Company size')['Latent_seizing'].apply(list)
f_stat, p_value = f_oneway(*groups)

print("\nClassical ANOVA results:")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# 2. Check if significant
if p_value < 0.05:
    print("\nANOVA is significant (p < 0.05). Applying Tukey HSD test...")

    # 3. Tukey HSD post-hoc test
    tukey = pairwise_tukeyhsd(endog=df_analysis_multivariate_final['Latent_seizing'],
                              groups=df_analysis_multivariate_final['Company size'],
                              alpha=0.05)
    tukey_summary = pd.DataFrame(data=tukey.summary().data[1:], columns=tukey.summary().data[0])
    tukey_summary['Interpretation'] = tukey_summary['p-adj'].apply(lambda x: 'Different' if x < 0.05 else 'Equal')

    # 4. Compute medians by group and sort
    medians = df_analysis_multivariate_final.groupby('Company size')['Latent_seizing'].median().reset_index()
    category_order = medians.sort_values('Latent_seizing', ascending=False)['Company size'].tolist()

    # 5. Create figure (boxplot + table)
    fig, ax = plt.subplots(2, 1, figsize=(8, 8), gridspec_kw={'height_ratios': [3, 1]})

    sns.boxplot(x='Company size', y='Latent_seizing', data=df_analysis_multivariate_final,
                ax=ax[0], palette="Set2", order=category_order)
    ax[0].set_title("Seizing by Company Size")
    ax[0].set_xlabel("Company Size")
    ax[0].set_ylabel("Latent Variable (Seizing)")

    # Annotate medians
    for i, row in medians.iterrows():
        idx = category_order.index(row['Company size'])
        offset = 0.05
        ax[0].text(idx, row['Latent_seizing'] + offset, 
                   f"{row['Latent_seizing']:.2f}", 
                   ha='center', va='bottom', fontweight='bold', color='black',
                   bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.05', linewidth=0.3))

    # 6. Add table below the plot
    table = tukey_summary[['group1', 'group2', 'Interpretation']]
    ax[1].axis('off')
    table_text = table.values.tolist()
    column_labels = ['Group 1', 'Group 2', 'Comparison']
    ax[1].table(cellText=table_text, colLabels=column_labels, loc='center', cellLoc='center')

    plt.tight_layout()
    plt.show()

else:
    print("\nANOVA is not significant (p ≥ 0.05). Tukey HSD test and plot will not be generated.")
# Out:
# Classical ANOVA results:
# F-statistic: 9.6422
# P-value: 0.0002
#
# ANOVA is significant (p < 0.05). Applying Tukey HSD test...
# C:\Users\monte\AppData\Local\Temp\ipykernel_11732\2993149322.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Company size', y='Latent_seizing', data=df_analysis_multivariate_final,

# %% [markdown]
# ### **2.3.2 Ventas de la empresa**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from scipy.stats import pearsonr

# Copia del dataframe
df_plot = df_analysis_multivariate_final.copy()

# Variables específicas
x_var = "Latent_seizing"
y_var = "Last year sales"

# Cálculo del coeficiente de correlación de Pearson
r, p_value = pearsonr(df_plot[x_var], df_plot[y_var])

# Resultados
print(f"Pearson correlation coefficient: r = {r:.4f}")
print(f"p-value: {p_value:.4f}")

# Interpretación
alpha = 0.05
if p_value < alpha:
    print(f"There is significant evidence of a linear correlation between '{x_var}' and '{y_var}'.")
else:
    print(f"No significant evidence of a linear correlation was found between '{x_var}' and '{y_var}'.")

# Gráfico con línea de regresión y banda de confianza
plt.figure(figsize=(8, 6))
sns.regplot(data=df_plot, x=x_var, y=y_var, ci=95, line_kws={'color': 'red'})
plt.title(f"Correlation between Latent Variable (Seizing) and Last Year Sales\nr = {r:.2f}, p = {p_value:.4f}", fontsize=14)
plt.xlabel("Latent Variable (Seizing)")
plt.ylabel("Last Year Sales (in millions)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Pearson correlation coefficient: r = 0.5368
# p-value: 0.0032
# There is significant evidence of a linear correlation between 'Latent_seizing' and 'Last year sales'.

# %%
df_promedio_empresa_corr=df_analysis_multivariate_final.copy()

# Cammbio de nombre de Indice_Sensing
df_promedio_empresa_corr.rename(columns={'Latent_seizing': 'Latent variable (Seizing)'}, inplace=True)

# Elegir las columnas que se desean analizar
df_promedio_empresa_corr = df_promedio_empresa_corr[["Latent variable (Seizing)","Company size","Last year sales"]]

categorical_features=identify_nominal_columns(df_promedio_empresa_corr)
continuous_features=identify_numeric_columns(df_promedio_empresa_corr)

# %%
from dython.nominal import associations
target_correlation= associations(df_promedio_empresa_corr, display_rows=["Latent variable (Seizing)"], filename= 'target_correlation.png', figsize=(20,5))
# Out:
# C:\Users\monte\AppData\Roaming\Python\Python311\site-packages\dython\nominal.py:736: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   inf_nan.loc[columns[i], columns[j]] = _inf_nan_str(ij)
# C:\Users\monte\AppData\Roaming\Python\Python311\site-packages\dython\nominal.py:737: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   inf_nan.loc[columns[j], columns[i]] = _inf_nan_str(ji)
# C:\Users\monte\AppData\Roaming\Python\Python311\site-packages\dython\nominal.py:736: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   inf_nan.loc[columns[i], columns[j]] = _inf_nan_str(ij)

# %%
df_promedio_empresa_reg_lineal = df_analysis_multivariate_final[["Latent_seizing","Last year sales"]]

x=df_promedio_empresa_reg_lineal.drop(["Last year sales"], axis=1)
y=df_promedio_empresa_reg_lineal["Last year sales"]
X = sm.add_constant(x) 
model = sm.OLS(y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Last year sales   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.261
# Method:                 Least Squares   F-statistic:                     10.52
# Date:               dom, 15 jun. 2025   Prob (F-statistic):            0.00323
# Time:                        12:41:26   Log-Likelihood:                -327.34
# No. Observations:                  28   AIC:                             658.7
# Df Residuals:                      26   BIC:                             661.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           2.955e+04   5668.290      5.214      0.000    1.79e+04    4.12e+04
# Latent_seizing  2.178e+04   6714.161      3.244      0.003    7979.479    3.56e+04
# ==============================================================================
# Omnibus:                        3.886   Durbin-Watson:                   1.496
# Prob(Omnibus):                  0.143   Jarque-Bera (JB):                3.469
# Skew:                           0.824   Prob(JB):                        0.177
# Kurtosis:                       2.492   Cond. No.                         1.18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Comprobación de supuestos:**

# %% [markdown]
# **I) Linealidad**

# %%
# Extrae las columnas Y y X del DataFrame
Y = df_analysis_multivariate_final['Last year sales']
X = df_analysis_multivariate_final['Latent_seizing']

# %%
# Calcula el coeficiente de correlación de Pearson y el valor p
correlation_coefficient, p_value = stats.pearsonr(Y, X)

# nivel de significancia (alpha)
alpha = 0.05

# Comparar el valor p con el nivel de significancia
if p_value < alpha:
    print("Hay evidencia de una relación lineal significativa (p < alpha)")
else:
    print("No hay evidencia de una relación lineal significativa (p >= alpha)")

print(f"Coeficiente de correlación de Pearson: {correlation_coefficient}")
# Out:
# Hay evidencia de una relación lineal significativa (p < alpha)
# Coeficiente de correlación de Pearson: 0.5367758501220242

# %% [markdown]
# **II) Independencia de errores**

# %%
errores = result.resid
errores_i_1 = errores[:-1]
errores_i = errores[1:]

plt.scatter(errores_i_1, errores_i,c='blue', marker='o',alpha=0.6)
plt.title('Gráfico de Dispersión de Error(i-1) vs Error(i)')
plt.xlabel('Error (i-1)')
plt.ylabel('Error (i)')
# Out:
# Text(0, 0.5, 'Error (i)')

# %% [markdown]
# **III) Homocedasticidad**

# %%
# Calcula los valores ajustados del modelo
valores_ajustados = result.fittedvalues

# Gráfico de dispersión de residuos vs valores ajustados
plt.scatter(valores_ajustados, errores, c='blue', marker='o', alpha=0.6)
plt.xlabel('Valores Ajustados')
plt.ylabel('Residuos')
plt.title('Gráfico de Residuos vs. Valores Ajustados')
plt.show()

# %%
# Suponiendo que 'modelo' es tu modelo de regresión ajustado
prueba_homocedasticidad = het_breuschpagan(errores, result.model.exog)

# La prueba devuelve varios valores, puedes ver el p-valor así:
p_valor = prueba_homocedasticidad[3]

print(f"P-valor asociado a la prueba Breusch Pagan: {p_valor}")
# Out:
# P-valor asociado a la prueba Breusch Pagan: 0.6808357863472702

# %% [markdown]
# Las hipótesis asociadas a esta prueba son las siguientes:
#
# - **HO: e_i son homocedásticos** (homogeneidad de la varianza)
# - **H1: e_i no son homocedásticos** (heterogeneidad de la varianza)
#
# En este caso, el p-valor asociado a la prueba de Breusch-Pagan es mayor a un nivel de significancia de 0.05, lo que lleva a aceptar la hipótesis nula de homocedasticidad. En este sentido, se concluye que **el modelo cumple con el supuesto de homocedasticidad en la varianza de los errores**.

# %% [markdown]
# **IV) Normalidad de los residuos**

# %%
sns.histplot(errores, kde=True)
plt.xlabel('Residuos')
plt.ylabel('Frecuencia')
plt.title('Histograma de Residuos')
plt.show()

# %%
# Crear el Q-Q plot
sm.qqplot(errores, line='s')  # 's' = línea de referencia con pendiente 1 (esperada si es normal)
plt.title("Q-Q Plot de los residuos")
plt.show()

# %%
# Aplicar la prueba de Shapiro-Wilk
stat, p = shapiro(errores)

# Mostrar el resultado
print("📊 Prueba de normalidad Shapiro-Wilk")
print(f"Estadístico W: {stat:.4f}")
print(f"Valor p: {p:.4f}")

# Interpretación
if p < 0.05:
    print("❌ Rechazamos H₀: los datos no siguen una distribución normal.")
else:
    print("✅ No se rechaza H₀: no hay evidencia de no normalidad.")
# Out:
# 📊 Prueba de normalidad Shapiro-Wilk
# Estadístico W: 0.8688
# Valor p: 0.0023
# ❌ Rechazamos H₀: los datos no siguen una distribución normal.

# %% [markdown]
# El modelo OLS clásico cumple con todos los supuestos, menos con el de normalidad. En este caso, es necesario aplicar una transformación a la variable dependiente para que los residuos se ajusten a una distribución normal. Una opción es aplicar una transformación logarítmica a la variable dependiente, que en este caso es "Last year sales". Se procede con esta transformación.

# %%
# Si hay valores positivos, podemos aplicar log
y_log = np.log(df_analysis_multivariate_final['Last year sales'])

# Variable independiente
X = df_analysis_multivariate_final['Latent_seizing']
X_const = sm.add_constant(X)

# Ajustar modelo con Y transformada
modelo_log = sm.OLS(y_log, X_const).fit()

# Residuales del modelo logarítmico
residuos_log = modelo_log.resid

# Resumen del modelo
modelo_log.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Last year sales   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     1.926
# Date:               dom, 15 jun. 2025   Prob (F-statistic):              0.177
# Time:                        12:53:51   Log-Likelihood:                -54.872
# No. Observations:                  28   AIC:                             113.7
# Df Residuals:                      26   BIC:                             116.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              9.2934      0.337     27.593      0.000       8.601       9.986
# Latent_seizing     0.5536      0.399      1.388      0.177      -0.266       1.374
# ==============================================================================
# Omnibus:                        5.010   Durbin-Watson:                   1.456
# Prob(Omnibus):                  0.082   Jarque-Bera (JB):                3.751
# Skew:                          -0.889   Prob(JB):                        0.153
# Kurtosis:                       3.233   Cond. No.                         1.18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Nueva comprobación de supuestos**

# %% [markdown]
# **I) Linealidad**

# %%
# Calcula el coeficiente de correlación de Pearson y el valor p
correlation_coefficient, p_value = stats.pearsonr(y_log, X)

# nivel de significancia (alpha)
alpha = 0.05

# Comparar el valor p con el nivel de significancia
if p_value < alpha:
    print("Hay evidencia de una relación lineal significativa (p < alpha)")
else:
    print("No hay evidencia de una relación lineal significativa (p >= alpha)")

print(f"Coeficiente de correlación de Pearson: {correlation_coefficient}")
# Out:
# No hay evidencia de una relación lineal significativa (p >= alpha)
# Coeficiente de correlación de Pearson: 0.26260235912813695

# %% [markdown]
# **II) Independencia de errores**

# %%
errores = modelo_log.resid
errores_i_1 = errores[:-1]
errores_i = errores[1:]

plt.scatter(errores_i_1, errores_i,c='blue', marker='o',alpha=0.6)
plt.title('Gráfico de Dispersión de Error(i-1) vs Error(i)')
plt.xlabel('Error (i-1)')
plt.ylabel('Error (i)')
# Out:
# Text(0, 0.5, 'Error (i)')

# %% [markdown]
# **III) Homocedasticidad**

# %%
# Calcula los valores ajustados del modelo
valores_ajustados = modelo_log.fittedvalues

# Gráfico de dispersión de residuos vs valores ajustados
plt.scatter(valores_ajustados, errores, c='blue', marker='o', alpha=0.6)
plt.xlabel('Valores Ajustados')
plt.ylabel('Residuos')
plt.title('Gráfico de Residuos vs. Valores Ajustados')
plt.show()

# %%
# Suponiendo que 'modelo' es tu modelo de regresión ajustado
prueba_homocedasticidad = het_breuschpagan(errores, modelo_log.model.exog)

# La prueba devuelve varios valores, puedes ver el p-valor así:
p_valor = prueba_homocedasticidad[3]

print(f"P-valor asociado a la prueba Breusch Pagan: {p_valor}")
# Out:
# P-valor asociado a la prueba Breusch Pagan: 0.35887708200456025

# %% [markdown]
# Las hipótesis asociadas a esta prueba son las siguientes:
#
# - **HO: e_i son homocedásticos** (homogeneidad de la varianza)
# - **H1: e_i no son homocedásticos** (heterogeneidad de la varianza)
#
# En este caso, el p-valor asociado a la prueba de Breusch-Pagan es mayor a un nivel de significancia de 0.05, lo que lleva a no tener evidencia para recharzar la hipótesis nula de homocedasticidad. En este sentido, se concluye que **el modelo SÍ cumple con el supuesto de homocedasticidad en la varianza de los errores**.

# %% [markdown]
# **IV) Normalidad de los residuos**

# %%
sns.histplot(errores, kde=True)
plt.xlabel('Residuos')
plt.ylabel('Frecuencia')
plt.title('Histograma de Residuos')
plt.show()

# %%
# Crear el Q-Q plot
sm.qqplot(errores, line='s')  # 's' = línea de referencia con pendiente 1 (esperada si es normal)
plt.title("Q-Q Plot de los residuos")
plt.show()

# %%
# Aplicar la prueba de Shapiro-Wilk
stat, p = shapiro(errores)

# Mostrar el resultado
print("📊 Prueba de normalidad Shapiro-Wilk")
print(f"Estadístico W: {stat:.4f}")
print(f"Valor p: {p:.4f}")

# Interpretación
if p < 0.05:
    print("❌ Rechazamos H₀: los datos no siguen una distribución normal.")
else:
    print("✅ No se rechaza H₀: no hay evidencia de no normalidad.")
# Out:
# 📊 Prueba de normalidad Shapiro-Wilk
# Estadístico W: 0.9278
# Valor p: 0.0544
# ✅ No se rechaza H₀: no hay evidencia de no normalidad.

# %% [markdown]
# ¿What to do?

# %% [markdown]
# ### **2.3.3 Industria de la empresa**

# %% [markdown]
# #### **Comprobación de normalidad de los datos**

# %%
# Aplicar Shapiro-Wilk a cada grupo
for group in df_analysis_multivariate_final['Industry'].unique():
    datos_grupo = df_analysis_multivariate_final[df_analysis_multivariate_final['Industry'] == group]['Latent_seizing']
    stat, p = shapiro(datos_grupo)
    print(f"\nGrupo: {group}")
    print(f"Estadístico Shapiro-Wilk: {stat:.4f}, p-valor: {p:.4f}")
    if p < 0.05:
        print("→ No es normal (rechaza H0)")
    else:
        print("→ Normal (no rechaza H0)")
# Out:
# Grupo: Manufacturing
# Estadístico Shapiro-Wilk: 0.8879, p-valor: 0.0755
# → Normal (no rechaza H0)
#
# Grupo: Services
# Estadístico Shapiro-Wilk: 0.9520, p-valor: 0.7318
# → Normal (no rechaza H0)
#
# Grupo: Commerce
# Estadístico Shapiro-Wilk: 0.8337, p-valor: 0.1154
# → Normal (no rechaza H0)

# %% [markdown]
# #### **Comprobación de homogeneidad de varianzas**

# %%
# Agrupar los datos por grupo
grupos = df_analysis_multivariate_final['Industry'].unique()
datos_por_grupo = [df_analysis_multivariate_final[df_analysis_multivariate_final['Industry'] == g]['Latent_seizing'] for g in grupos]

# Aplicar prueba de Levene
stat, p = levene(*datos_por_grupo)
print(f"Estadístico Levene: {stat:.4f}, p-valor: {p:.4f}")

if p < 0.05:
    print("→ Varianzas diferentes (rechaza H0)")
else:
    print("→ Varianzas iguales (no rechaza H0)")
# Out:
# Estadístico Levene: 0.9450, p-valor: 0.4021
# → Varianzas iguales (no rechaza H0)

# %% [markdown]
# #### **Aplicación de pruebas estadísticas para revisión de diferencias entre medias**

# %%
# 1. Classical ANOVA
groups = df_analysis_multivariate_final.groupby('Industry')['Latent_seizing'].apply(list)
f_stat, p_value = f_oneway(*groups)

print("\nClassical ANOVA results:")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# 2. Check if significant
if p_value < 0.05:
    print("\nANOVA is significant (p < 0.05). Applying Tukey HSD test...")

    # 3. Tukey HSD post-hoc test
    tukey = pairwise_tukeyhsd(endog=df_analysis_multivariate_final['Latent_seizing'],
                              groups=df_analysis_multivariate_final['Industry'],
                              alpha=0.05)
    tukey_summary = pd.DataFrame(data=tukey.summary().data[1:], columns=tukey.summary().data[0])
    tukey_summary['Interpretation'] = tukey_summary['p-adj'].apply(lambda x: 'Different' if x < 0.05 else 'Equal')

    # 4. Compute medians by group and sort
    medians = df_analysis_multivariate_final.groupby('Industry')['Latent_seizing'].median().reset_index()
    category_order = medians.sort_values('Latent_seizing', ascending=False)['Industry'].tolist()

    # 5. Create figure (boxplot + table)
    fig, ax = plt.subplots(2, 1, figsize=(9, 8), gridspec_kw={'height_ratios': [3, 1]})

    sns.boxplot(x='Industry', y='Latent_seizing', data=df_analysis_multivariate_final,
                ax=ax[0], palette="Set2", order=category_order)
    ax[0].set_title("Latent Variable (Seizing) by Industry", fontsize=14)
    ax[0].set_xlabel("Industry")
    ax[0].set_ylabel("Latent Variable (Seizing)")

    # Annotate medians
    for i, row in medians.iterrows():
        idx = category_order.index(row['Industry'])
        offset = 0.05
        ax[0].text(idx, row['Latent_seizing'] + offset, 
                   f"{row['Latent_seizing']:.2f}", 
                   ha='center', va='bottom', fontweight='bold', color='black',
                   bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.05', linewidth=0.3))

    # 6. Add table below the plot
    table = tukey_summary[['group1', 'group2', 'Interpretation']]
    ax[1].axis('off')
    table_text = table.values.tolist()
    column_labels = ['Group 1', 'Group 2', 'Comparison']
    ax[1].table(cellText=table_text, colLabels=column_labels, loc='center', cellLoc='center')

    plt.tight_layout()
    plt.show()

else:
    print("\nANOVA is not significant (p ≥ 0.05). Tukey HSD test and plot will not be generated.")
# Out:
# Classical ANOVA results:
# F-statistic: 0.1833
# P-value: 0.8337
#
# ANOVA is not significant (p ≥ 0.05). Tukey HSD test and plot will not be generated.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calcular las medianas y el orden personalizado
medians = df_analysis_multivariate_final.groupby('Industry')['Latent_seizing'].median().reset_index()
category_order = medians.sort_values('Latent_seizing', ascending=False)['Industry'].tolist()

# Crear figura con dos filas (boxplot + tabla informativa)
fig, ax = plt.subplots(2, 1, figsize=(9, 8), gridspec_kw={'height_ratios': [3, 1]})

# Boxplot ordenado por mediana
sns.boxplot(x='Industry', y='Latent_seizing', data=df_analysis_multivariate_final,
            ax=ax[0], palette="Set2", order=category_order)

ax[0].set_title("Latent Variable (Seizing) by Industry", fontsize=14)
ax[0].set_xlabel("Industry")
ax[0].set_ylabel("Latent Variable (Seizing)")
ax[0].grid(True)

# Anotar medianas en cada caja
for i, row in medians.iterrows():
    idx = category_order.index(row['Industry'])
    offset = 0.05
    ax[0].text(idx, row['Latent_seizing'] + offset, 
               f"{row['Latent_seizing']:.2f}", 
               ha='center', va='bottom', fontweight='bold', color='black',
               bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.05', linewidth=0.3))

# Tabla informativa: ANOVA no significativo
ax[1].axis('off')
table_text = [["ANOVA no significativo", "No se aplicaron comparaciones post-hoc"]]
column_labels = ["Resultado", "Interpretación"]
ax[1].table(cellText=table_text, colLabels=column_labels, loc='center', cellLoc='center')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\monte\AppData\Local\Temp\ipykernel_11732\796637643.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Industry', y='Latent_seizing', data=df_analysis_multivariate_final,

# %% [markdown]
# ### **2.3.4 Sectores de la empresa**

# %% [markdown]
# No se pueden aplicar pruebas estadísticas para revisar diferencias entre grupos para esta variable dado que para algunos sectores tenemos menos de 3 observaciones y es necesario tener al menos 3 observaciones para poder aplicar la prueba de Shapiro-Wilk, con el propósito de revisar normalidad.

# %% [markdown]
# ### **2.3.5 Ubicación geográfica de la empresa**

# %% [markdown]
# #### **Comprobación de normalidad de los datos**

# %%
from scipy.stats import shapiro

# Ejecutar la prueba de Shapiro-Wilk por grupo de 'Sector'
resultados_shapiro = []

for group in df_analysis_multivariate_final['Geographic reach location'].unique():
    datos_grupo = df_analysis_multivariate_final[df_analysis_multivariate_final['Geographic reach location'] == group]['Latent_sensing']
    
    # Evitar aplicar la prueba si hay menos de 3 observaciones (Shapiro requiere al menos 3)
    if len(datos_grupo) < 3:
        resultados_shapiro.append({
            "Geographic reach location": group,
            "N": len(datos_grupo),
            "Estadístico": None,
            "p-valor": None,
            "Normalidad": "No aplica (<3 observaciones)"
        })
        continue
    
    stat, p = shapiro(datos_grupo)
    normalidad = "Normal (no rechaza H0)" if p >= 0.05 else "No es normal (rechaza H0)"
    resultados_shapiro.append({
        "Geographic reach location": group,
        "N": len(datos_grupo),
        "Estadístico": stat,
        "p-valor": p,
        "Normalidad": normalidad
    })

import pandas as pd
df_shapiro = pd.DataFrame(resultados_shapiro)
df_shapiro
# Out:
#   Geographic reach location   N  Estadístico   p-valor  \
# 0                  Regional   2          NaN       NaN
# 1                  National   9     0.845919  0.067180
# 2                     Local  14     0.917688  0.203654
# 3             International   3     0.833903  0.198298
#
#                      Normalidad
# 0  No aplica (<3 observaciones)
# 1        Normal (no rechaza H0)
# 2        Normal (no rechaza H0)
# 3        Normal (no rechaza H0)

# %% [markdown]
# El número de empresas regional es apenas 2, por lo que no se puede comprobar normalidad en ese grupo. Por tanto, se excluye del análisis.

# %%
# Quitar registros con location regional
df_analysis_multivariate_final_location=df_analysis_multivariate_final[df_analysis_multivariate_final['Geographic reach location'] != 'Regional']

# %% [markdown]
# #### **Comprobación de homogeneidad de varianzas**

# %%
from scipy.stats import levene

# Agrupar los datos de 'Latent_seizing' por ubicación geográfica
grupos = df_analysis_multivariate_final_location.groupby('Geographic reach location')['Latent_seizing'].apply(list)

# Aplicar la prueba de Levene
stat_levene, p_levene = levene(*grupos)

# Mostrar resultados
print("📊 Resultado de la prueba de Levene (homogeneidad de varianzas)")
print("---------------------------------------------------------------")
print(f"Estadístico de Levene: {stat_levene:.4f}")
print(f"Valor p: {p_levene:.4f}")

# Interpretación
if p_levene < 0.05:
    print("→ Se rechaza la hipótesis nula: hay evidencia de que las varianzas no son iguales.")
else:
    print("→ No se rechaza la hipótesis nula: no hay evidencia de que las varianzas sean diferentes.")
# Out:
# 📊 Resultado de la prueba de Levene (homogeneidad de varianzas)
# ---------------------------------------------------------------
# Estadístico de Levene: 0.9783
# Valor p: 0.3911
# → No se rechaza la hipótesis nula: no hay evidencia de que las varianzas sean diferentes.

# %% [markdown]
# Se comprueba homogeneidad de varianzas para aplicar ANOVA.

# %%
# 1. Classical ANOVA
groups = df_analysis_multivariate_final.groupby('Geographic reach location')['Latent_seizing'].apply(list)
f_stat, p_value = f_oneway(*groups)

print("\nClassical ANOVA results:")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# 2. Check if significant
if p_value < 0.05:
    print("\nANOVA is significant (p < 0.05). Applying Tukey HSD test...")

    # 3. Tukey HSD post-hoc test
    tukey = pairwise_tukeyhsd(endog=df_analysis_multivariate_final['Latent_seizing'],
                              groups=df_analysis_multivariate_final['Geographic reach location'],
                              alpha=0.05)
    tukey_summary = pd.DataFrame(data=tukey.summary().data[1:], columns=tukey.summary().data[0])
    tukey_summary['Interpretation'] = tukey_summary['p-adj'].apply(lambda x: 'Different' if x < 0.05 else 'Equal')

    # 4. Compute medians by group and sort
    medians = df_analysis_multivariate_final.groupby('Geographic reach location')['Latent_seizing'].median().reset_index()
    category_order = medians.sort_values('Latent_seizing', ascending=False)['Geographic reach location'].tolist()

    # 5. Create figure (boxplot + table)
    fig, ax = plt.subplots(2, 1, figsize=(8, 8), gridspec_kw={'height_ratios': [3, 1]})

    sns.boxplot(x='Geographic reach location', y='Latent_seizing', data=df_analysis_multivariate_final,
                ax=ax[0], palette="Set2", order=category_order)
    ax[0].set_title("Latent Variable (Seizing) by Geographic Reach Location")
    ax[0].set_xlabel("Geographic Reach Location")
    ax[0].set_ylabel("Latent Variable (Seizing)")

    # Annotate medians
    for i, row in medians.iterrows():
        idx = category_order.index(row['Geographic reach location'])
        offset = 0.05
        ax[0].text(idx, row['Latent_seizing'] + offset, 
                   f"{row['Latent_seizing']:.2f}", 
                   ha='center', va='bottom', fontweight='bold', color='black',
                   bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.05', linewidth=0.3))

    # 6. Add table below the plot
    table = tukey_summary[['group1', 'group2', 'Interpretation']]
    ax[1].axis('off')
    table_text = table.values.tolist()
    column_labels = ['Group 1', 'Group 2', 'Comparison']
    ax[1].table(cellText=table_text, colLabels=column_labels, loc='center', cellLoc='center')

    plt.tight_layout()
    plt.show()

else:
    print("\nANOVA is not significant (p ≥ 0.05). Tukey HSD test and plot will not be generated.")
# Out:
# Classical ANOVA results:
# F-statistic: 1.0293
# P-value: 0.3973
#
# ANOVA is not significant (p ≥ 0.05). Tukey HSD test and plot will not be generated.

# %% [markdown]
# No hay evidencia estadísticamente significativa de que las medias del Indice_Sensing difieran entre las ubicaciones geográficas (National, Local, International).

# %%
# Calcular las medianas y el orden personalizado
medians = df_analysis_multivariate_final.groupby('Geographic reach location')['Latent_seizing'].median().reset_index()
category_order = medians.sort_values('Latent_seizing', ascending=False)['Geographic reach location'].tolist()

# Crear figura con dos filas (boxplot + tabla informativa)
fig, ax = plt.subplots(2, 1, figsize=(9, 8), gridspec_kw={'height_ratios': [3, 1]})

# Boxplot ordenado por mediana
sns.boxplot(x='Geographic reach location', y='Latent_seizing', data=df_analysis_multivariate_final,
            ax=ax[0], palette="Set2", order=category_order)

ax[0].set_title("Latent Variable (Seizing) by Geographic Reach Location", fontsize=14)
ax[0].set_xlabel("Geographic Reach Location")
ax[0].set_ylabel("Latent Variable (Seizing)")
ax[0].grid(True)

# Anotar medianas en cada caja
for i, row in medians.iterrows():
    idx = category_order.index(row['Geographic reach location'])
    offset = 0.05
    ax[0].text(idx, row['Latent_seizing'] + offset, 
               f"{row['Latent_seizing']:.2f}", 
               ha='center', va='bottom', fontweight='bold', color='black',
               bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.05', linewidth=0.3))

# Tabla informativa: ANOVA no significativo
ax[1].axis('off')
table_text = [["ANOVA no significativo", "No se aplicaron comparaciones post-hoc"]]
column_labels = ["Resultado", "Interpretación"]
ax[1].table(cellText=table_text, colLabels=column_labels, loc='center', cellLoc='center')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\monte\AppData\Local\Temp\ipykernel_11732\2704970385.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Geographic reach location', y='Latent_seizing', data=df_analysis_multivariate_final,

# %% [markdown]
# ### **2.3.6 Edad de la empresa**

# %%
# Pearson correlation coefficient and p-value calculation
r, p_value = pearsonr(df_analysis_multivariate_final['Latent_seizing'], df_analysis_multivariate_final['Age of company'])

# Results
print(f"Pearson correlation coefficient: r = {r:.4f}")
print(f"p-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("There is significant evidence of a linear correlation between 'Latent_seizing' and 'Age of company'.")
else:
    print("No significant evidence of a linear correlation was found between 'Latent_seizing' and 'Age of company'.")

# Visualization
plt.figure(figsize=(8, 6))
sns.regplot(data=df_analysis_multivariate_final, x='Age of company', y='Latent_seizing', ci=95, line_kws={'color': 'red'})
plt.title(f"Correlation between Latent Variable (Sensing) and Last Year Sales\nr = {r:.2f}, p = {p_value:.4f}")
plt.xlabel("Age of company")
plt.ylabel("Latent variable (Seizing)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Pearson correlation coefficient: r = -0.0235
# p-value: 0.9055
# No significant evidence of a linear correlation was found between 'Latent_seizing' and 'Age of company'.

# %%
# Nivel de significancia
alpha = 0.05

# Spearman
rho_spearman, p_spearman = spearmanr(df_analysis_multivariate_final['Latent_seizing'], df_analysis_multivariate_final['Age of company'])
print("=== Correlación de Spearman ===")
print(f"Coeficiente rho: {rho_spearman:.4f}")
print(f"Valor p: {p_spearman:.4f}")
if p_spearman < alpha:
    print("→ Existe una relación monótona significativa entre las variables (se rechaza H₀).")
else:
    print("→ No existe una relación monótona significativa entre las variables (no se rechaza H₀).")

print("\n")

# Kendall
tau_kendall, p_kendall = kendalltau(df_analysis_multivariate_final['Latent_seizing'], df_analysis_multivariate_final['Age of company'])
print("=== Correlación de Kendall ===")
print(f"Coeficiente tau: {tau_kendall:.4f}")
print(f"Valor p: {p_kendall:.4f}")
if p_kendall < alpha:
    print("→ Existe una relación significativa según Kendall (se rechaza H₀).")
else:
    print("→ No existe una relación significativa según Kendall (no se rechaza H₀).")
# Out:
# === Correlación de Spearman ===
# Coeficiente rho: 0.0578
# Valor p: 0.7700
# → No existe una relación monótona significativa entre las variables (no se rechaza H₀).
#
#
# === Correlación de Kendall ===
# Coeficiente tau: 0.0348
# Valor p: 0.7969
# → No existe una relación significativa según Kendall (no se rechaza H₀).

# %% [markdown]
# No se considera necesario avanzar hacia la aplicaciòn de una regresión lineal simple, ya que la prueba de correlación de Pearson ya ha indicado que no hay evidencia de una relación lineal significativa entre las variables 'Latent_sensing' y 'Age of company'.

# %% [markdown]
# ### **2.2.7 R&D Expenditure**

# %%
# Pearson correlation coefficient and p-value calculation
r, p_value = pearsonr(df_analysis_multivariate_final['Latent_seizing'], df_analysis_multivariate_final['R&D expenditure'])

# Results
print(f"Pearson correlation coefficient: r = {r:.4f}")
print(f"p-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("There is significant evidence of a linear correlation between 'Latent_seizing' and 'R&D expenditure'.")
else:
    print("No significant evidence of a linear correlation was found between 'Latent_seizing' and 'R&D expenditure'.")

# Visualization
plt.figure(figsize=(8, 6))
sns.regplot(data=df_analysis_multivariate_final, x='R&D expenditure', y='Latent_seizing', ci=95, line_kws={'color': 'red'})
plt.title(f"Correlation between Latent Variable (Seizing) and Last Year Sales\nr = {r:.2f}, p = {p_value:.4f}")
plt.xlabel("R&D expenditure")
plt.ylabel("Latent variable (Seizing)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Pearson correlation coefficient: r = -0.1368
# p-value: 0.4876
# No significant evidence of a linear correlation was found between 'Latent_seizing' and 'R&D expenditure'.

# %%
# Nivel de significancia
alpha = 0.05

# Spearman
rho_spearman, p_spearman = spearmanr(df_analysis_multivariate_final['Latent_seizing'], df_analysis_multivariate_final['R&D expenditure'])
print("=== Correlación de Spearman ===")
print(f"Coeficiente rho: {rho_spearman:.4f}")
print(f"Valor p: {p_spearman:.4f}")
if p_spearman < alpha:
    print("→ Existe una relación monótona significativa entre las variables (se rechaza H₀).")
else:
    print("→ No existe una relación monótona significativa entre las variables (no se rechaza H₀).")

print("\n")

# Kendall
tau_kendall, p_kendall = kendalltau(df_analysis_multivariate_final['Latent_seizing'], df_analysis_multivariate_final['R&D expenditure'])
print("=== Correlación de Kendall ===")
print(f"Coeficiente tau: {tau_kendall:.4f}")
print(f"Valor p: {p_kendall:.4f}")
if p_kendall < alpha:
    print("→ Existe una relación significativa según Kendall (se rechaza H₀).")
else:
    print("→ No existe una relación significativa según Kendall (no se rechaza H₀).")
# Out:
# === Correlación de Spearman ===
# Coeficiente rho: 0.2390
# Valor p: 0.2207
# → No existe una relación monótona significativa entre las variables (no se rechaza H₀).
#
#
# === Correlación de Kendall ===
# Coeficiente tau: 0.1790
# Valor p: 0.1932
# → No existe una relación significativa según Kendall (no se rechaza H₀).

# %% [markdown]
# ### **2.3.8 Number of patents innovations**

# %%
# Specific variables
df_plot = df_analysis_multivariate_final.copy()
y_var = "Latent_seizing"
x_var = "Number of patents innovations"

# Fit linear regression model
X = df_plot[[x_var]]  # design matrix (2D)
y = df_plot[y_var]
model = LinearRegression().fit(X, y)

# Predict values and compute R²
y_pred = model.predict(X)
r2 = r2_score(y, y_pred)

# Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x=x_var, y=y_var, data=df_plot, color='darkgreen', s=60)
sns.lineplot(x=df_plot[x_var], y=y_pred, color='red', linewidth=2, label='Linear regression')

# Customize labels and title
plt.title("Relationship between Latent Variable (Seizing) and Number of patent innovations", fontsize=14)
plt.xlabel("Latent Variable (Seizing)")
plt.ylabel("Number of patent innovations")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_promedio_empresa_corr=df_analysis_multivariate_final.copy()

# Cammbio de nombre de Indice_Sensing
df_promedio_empresa_corr.rename(columns={'Indice_Seizing': 'Latent_seizing'}, inplace=True)

# Elegir las columnas que se desean analizar
df_promedio_empresa_corr = df_promedio_empresa_corr[["Latent_seizing","Number of patents innovations"]]

categorical_features=identify_nominal_columns(df_promedio_empresa_corr)
continuous_features=identify_numeric_columns(df_promedio_empresa_corr)

# %%
from dython.nominal import associations
target_correlation= associations(df_promedio_empresa_corr, display_rows=["Latent_seizing"], filename= 'target_correlation.png', figsize=(20,5))
# Out:
# C:\Users\monte\AppData\Roaming\Python\Python311\site-packages\dython\nominal.py:736: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   inf_nan.loc[columns[i], columns[j]] = _inf_nan_str(ij)
# C:\Users\monte\AppData\Roaming\Python\Python311\site-packages\dython\nominal.py:737: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   inf_nan.loc[columns[j], columns[i]] = _inf_nan_str(ji)

# %%
from scipy.stats import spearmanr

# Supongamos que tienes dos variables en un DataFrame
x = df_analysis_multivariate_final['Latent_seizing']
y = df_analysis_multivariate_final['R&D expenditure']

# Calcular la correlación de Spearman
coef, p_value = spearmanr(x, y)

print(f"Coeficiente de Spearman: {coef:.4f}")
print(f"Valor p: {p_value:.4f}")

# Interpretación
if p_value < 0.05:
    print("✔️ La correlación es estadísticamente significativa.")
else:
    print("❌ No hay evidencia de una correlación significativa.")
# Out:
# Coeficiente de Spearman: 0.2390
# Valor p: 0.2207
# ❌ No hay evidencia de una correlación significativa.

# %%
from scipy.stats import kendalltau

# Supón que tienes tus dos variables en un DataFrame
x = df_analysis_multivariate_final['Latent_seizing']
y = df_analysis_multivariate_final['R&D expenditure']

# Calcular la correlación de Kendall
coef, p_value = kendalltau(x, y)

print(f"Coeficiente de Kendall τ: {coef:.4f}")
print(f"Valor p: {p_value:.4f}")

# Interpretación
if p_value < 0.05:
    print("✔️ La correlación es estadísticamente significativa.")
else:
    print("❌ No hay evidencia de una correlación significativa.")
# Out:
# Coeficiente de Kendall τ: 0.1790
# Valor p: 0.1932
# ❌ No hay evidencia de una correlación significativa.

# %%
df_promedio_empresa_reg_lineal = df_analysis_multivariate_final[["Latent_seizing","Number of patents innovations"]]

x=df_promedio_empresa_reg_lineal.drop(["Latent_seizing"], axis=1)
y=df_promedio_empresa_reg_lineal["Latent_seizing"]
X = sm.add_constant(x) 
model = sm.OLS(y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Latent_seizing   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.7859
# Date:               dom, 15 jun. 2025   Prob (F-statistic):              0.383
# Time:                        13:37:29   Log-Likelihood:                -34.572
# No. Observations:                  28   AIC:                             73.14
# Df Residuals:                      26   BIC:                             75.81
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                            -0.1839      0.259     -0.709      0.485      -0.717       0.349
# Number of patents innovations     0.0544      0.061      0.887      0.383      -0.072       0.181
# ==============================================================================
# Omnibus:                       11.691   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.795
# Skew:                           1.002   Prob(JB):                      0.00167
# Kurtosis:                       5.637   Cond. No.                         6.95
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **I) Linealidad**

# %%
# Extrae las columnas Y y X del DataFrame
Y = df_analysis_multivariate_final['Number of patents innovations']
X = df_analysis_multivariate_final['Latent_seizing']

# %%
# Calcula el coeficiente de correlación de Pearson y el valor p
correlation_coefficient, p_value = stats.pearsonr(Y, X)

# nivel de significancia (alpha)
alpha = 0.05

# Comparar el valor p con el nivel de significancia
if p_value < alpha:
    print("Hay evidencia de una relación lineal significativa (p < alpha)")
else:
    print("No hay evidencia de una relación lineal significativa (p >= alpha)")

print(f"Coeficiente de correlación de Pearson: {correlation_coefficient}")
# Out:
# No hay evidencia de una relación lineal significativa (p >= alpha)
# Coeficiente de correlación de Pearson: 0.17128798308587928

# %% [markdown]
# **II) Independencia de errores**

# %%
errores = result.resid
errores_i_1 = errores[:-1]
errores_i = errores[1:]

plt.scatter(errores_i_1, errores_i,c='blue', marker='o',alpha=0.6)
plt.title('Gráfico de Dispersión de Error(i-1) vs Error(i)')
plt.xlabel('Error (i-1)')
plt.ylabel('Error (i)')
# Out:
# Text(0, 0.5, 'Error (i)')

# %% [markdown]
# **III) Homocedasticidad**

# %%
# Calcula los valores ajustados del modelo
valores_ajustados = result.fittedvalues

# Gráfico de dispersión de residuos vs valores ajustados
plt.scatter(valores_ajustados, errores, c='blue', marker='o', alpha=0.6)
plt.xlabel('Valores Ajustados')
plt.ylabel('Residuos')
plt.title('Gráfico de Residuos vs. Valores Ajustados')
plt.show()

# %%
# Suponiendo que 'modelo' es tu modelo de regresión ajustado
prueba_homocedasticidad = het_breuschpagan(errores, result.model.exog)

# La prueba devuelve varios valores, puedes ver el p-valor así:
p_valor = prueba_homocedasticidad[3]

print(f"P-valor asociado a la prueba Breusch Pagan: {p_valor}")
# Out:
# P-valor asociado a la prueba Breusch Pagan: 0.9381640487949556

# %% [markdown]
# Las hipótesis asociadas a esta prueba son las siguientes:
#
# - **HO: e_i son homocedásticos** (homogeneidad de la varianza)
# - **H1: e_i no son homocedásticos** (heterogeneidad de la varianza)
#
# En este caso, el p-valor asociado a la prueba de Breusch-Pagan es mayor a un nivel de significancia de 0.05, lo que lleva a aceptar la hipótesis nula de homocedasticidad. En este sentido, se concluye que **el modelo cumple con el supuesto de homocedasticidad en la varianza de los errores**.

# %% [markdown]
# **IV) Normalidad de los residuos**

# %%
sns.histplot(errores, kde=True)
plt.xlabel('Residuos')
plt.ylabel('Frecuencia')
plt.title('Histograma de Residuos')
plt.show()

# %%
# Crear el Q-Q plot
sm.qqplot(errores, line='s')  # 's' = línea de referencia con pendiente 1 (esperada si es normal)
plt.title("Q-Q Plot de los residuos")
plt.show()

# %%
# Aplicar la prueba de Shapiro-Wilk
stat, p = shapiro(errores)

# Mostrar el resultado
print("📊 Prueba de normalidad Shapiro-Wilk")
print(f"Estadístico W: {stat:.4f}")
print(f"Valor p: {p:.4f}")

# Interpretación
if p < 0.05:
    print("❌ Rechazamos H₀: los datos no siguen una distribución normal.")
else:
    print("✅ No se rechaza H₀: no hay evidencia de no normalidad.")
# Out:
# 📊 Prueba de normalidad Shapiro-Wilk
# Estadístico W: 0.9085
# Valor p: 0.0182
# ❌ Rechazamos H₀: los datos no siguen una distribución normal.

# %% [markdown]
# ## **2.4 Análisis bivariados - Índice Transformation**

# %% [markdown]
# #### **Comprobación de normalidad de los datos**

# %%
# Aplicar Shapiro-Wilk a cada grupo
for group in df_analysis_multivariate_final['Company size'].unique():
    datos_grupo = df_analysis_multivariate_final[df_analysis_multivariate_final['Company size'] == group]['Indice_Transformation']
    stat, p = shapiro(datos_grupo)
    print(f"\nGrupo: {group}")
    print(f"Estadístico Shapiro-Wilk: {stat:.4f}, p-valor: {p:.4f}")
    if p < 0.05:
        print("→ No es normal (rechaza H0)")
    else:
        print("→ Normal (no rechaza H0)")

# %% [markdown]
# #### **Comprobación de homogeneidad de varianzas**

# %%
# Agrupar los datos por grupo
grupos = df_analysis_multivariate_final['Company size'].unique()
datos_por_grupo = [df_analysis_multivariate_final[df_analysis_multivariate_final['Company size'] == g]['Indice_Transformation'] for g in grupos]

# Aplicar prueba de Levene
stat, p = levene(*datos_por_grupo)
print(f"Estadístico Levene: {stat:.4f}, p-valor: {p:.4f}")

if p < 0.05:
    print("→ Varianzas diferentes (rechaza H0)")
else:
    print("→ Varianzas iguales (no rechaza H0)")

# %% [markdown]
# #### **Aplicación de pruebas estadísticas para revisión de diferencias entre medianas**

# %%
# 1. Classical ANOVA
groups = df_analysis_multivariate_final.groupby('Company size')['Indice_Transformation'].apply(list)
f_stat, p_value = f_oneway(*groups)

print("\nClassical ANOVA results:")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# 2. Check if significant
if p_value < 0.05:
    print("\nANOVA is significant (p < 0.05). Applying Tukey HSD test...")

    # 3. Tukey HSD post-hoc test
    tukey = pairwise_tukeyhsd(endog=df_analysis_multivariate_final['Indice_Transformation'],
                              groups=df_analysis_multivariate_final['Company size'],
                              alpha=0.05)
    tukey_summary = pd.DataFrame(data=tukey.summary().data[1:], columns=tukey.summary().data[0])
    tukey_summary['Interpretation'] = tukey_summary['p-adj'].apply(lambda x: 'Different' if x < 0.05 else 'Equal')

    # 4. Compute medians by group and sort
    medians = df_analysis_multivariate_final.groupby('Company size')['Indice_Transformation'].median().reset_index()
    category_order = medians.sort_values('Indice_Transformation', ascending=False)['Company size'].tolist()

    # 5. Create figure (boxplot + table)
    fig, ax = plt.subplots(2, 1, figsize=(8, 8), gridspec_kw={'height_ratios': [3, 1]})

    sns.boxplot(x='Company size', y='Indice_Transformation', data=df_analysis_multivariate_final,
                ax=ax[0], palette="Set2", order=category_order)
    ax[0].set_title("Transformation by Company Size")
    ax[0].set_xlabel("Company Size")
    ax[0].set_ylabel("Latent Variable (Transformation)")

    # Annotate medians
    for i, row in medians.iterrows():
        idx = category_order.index(row['Company size'])
        offset = 0.05
        ax[0].text(idx, row['Indice_Transformation'] + offset, 
                   f"{row['Indice_Transformation']:.2f}", 
                   ha='center', va='bottom', fontweight='bold', color='black',
                   bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.05', linewidth=0.3))

    # 6. Add table below the plot
    table = tukey_summary[['group1', 'group2', 'Interpretation']]
    ax[1].axis('off')
    table_text = table.values.tolist()
    column_labels = ['Group 1', 'Group 2', 'Comparison']
    ax[1].table(cellText=table_text, colLabels=column_labels, loc='center', cellLoc='center')

    plt.tight_layout()
    plt.show()

else:
    print("\nANOVA is not significant (p ≥ 0.05). Tukey HSD test and plot will not be generated.")

# %% [markdown]
# ### **2.4.2 Ventas de la empresa**

# %%
# Specific variables
df_plot = df_analysis_multivariate_final.copy()
x_var = "Indice_Transformation"
y_var = "Last year sales"

# Fit linear regression model
X = df_plot[[x_var]]  # design matrix (2D)
y = df_plot[y_var]
model = LinearRegression().fit(X, y)

# Predict values and compute R²
y_pred = model.predict(X)
r2 = r2_score(y, y_pred)

# Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x=x_var, y=y_var, data=df_plot, color='darkgreen', s=60)
sns.lineplot(x=df_plot[x_var], y=y_pred, color='red', linewidth=2, label='Linear regression')

# Customize labels and title
plt.title("Relationship between Latent Variable (Transformation) and Last Year Sales", fontsize=14)
plt.xlabel("Latent Variable (Transformation)")
plt.ylabel("Last Year Sales (in millions)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_promedio_empresa_corr=df_analysis_multivariate_final.copy()

# Cammbio de nombre de Indice_Sensing
df_promedio_empresa_corr.rename(columns={'Indice_Transformation': 'Latent variable (Transformation)'}, inplace=True)

# Elegir las columnas que se desean analizar
df_promedio_empresa_corr = df_promedio_empresa_corr[["Latent variable (Transformation)","Company size","Last year sales"]]

categorical_features=identify_nominal_columns(df_promedio_empresa_corr)
continuous_features=identify_numeric_columns(df_promedio_empresa_corr)

# %%
from dython.nominal import associations
target_correlation= associations(df_promedio_empresa_corr, display_rows=["Latent variable (Transformation)"], filename= 'target_correlation.png', figsize=(20,5))

# %%
df_promedio_empresa_reg_lineal = df_analysis_multivariate_final[["Indice_Transformation","Last year sales"]]

x=df_promedio_empresa_reg_lineal.drop(["Last year sales"], axis=1)
y=df_promedio_empresa_reg_lineal["Last year sales"]
X = sm.add_constant(x) 
model = sm.OLS(y,X)
result=model.fit()
result.summary()

# %% [markdown]
# ### **2.4.3 Industria de la empresa**

# %% [markdown]
# #### **Comprobación de normalidad de los datos**

# %%
# Aplicar Shapiro-Wilk a cada grupo
for group in df_analysis_multivariate_final['Industry'].unique():
    datos_grupo = df_analysis_multivariate_final[df_analysis_multivariate_final['Industry'] == group]['Latent_transformation']
    stat, p = shapiro(datos_grupo)
    print(f"\nGrupo: {group}")
    print(f"Estadístico Shapiro-Wilk: {stat:.4f}, p-valor: {p:.4f}")
    if p < 0.05:
        print("→ No es normal (rechaza H0)")
    else:
        print("→ Normal (no rechaza H0)")

# %%
# Agrupar los valores de Indice_Transformation por categoría en Industry
groups = df_analysis_multivariate_final.groupby('Industry')['Latent_transformation'].apply(list)

# Aplicar la prueba de Kruskal-Wallis
stat, p_value = kruskal(*groups)

print(f'Estadístico H: {stat:.4f}')
print(f'Valor p: {p_value:.4f}')

# Interpretación del resultado
if p_value < 0.05:
    print("Hay diferencias estadísticamente significativas en Indice_Transformation entre al menos dos industrias.")
else:
    print("No hay diferencias estadísticamente significativas en Indice_Transformation entre las industrias.")

# %%
fig_boxplot = plt.figure(figsize=(10,5)) 
ax = fig_boxplot.add_axes([0,0,1,1])

resumen=df_analysis_multivariate_final.groupby(by=["Industry"])["Latent_transformation"].describe()

ax=sns.boxplot(x=df_analysis_multivariate_final["Industry"], y=df_analysis_multivariate_final["Latent_transformation"],order=resumen.sort_values(by='50%', ascending=False).index)
plt.ylabel('')   
plt.xlabel('')           
plt.show()

# %% [markdown]
# No hay diferencias estadísticamente significativas en los valores del Indice_Transformation entre los distintos grupos de la variable Industry. No será necesaria prueba post-hoc.

# %% [markdown]
# ### **2.4.4 Sectores de la empresa**

# %% [markdown]
# No se pueden aplicar pruebas estadísticas para revisar diferencias entre grupos para esta variable dado que para algunos sectores tenemos menos de 3 observaciones y es necesario tener al menos 3 observaciones para poder aplicar la prueba de Shapiro-Wilk, con el propósito de revisar normalidad.

# %%
df_analysis_multivariate_final['Sector'].value_counts()

# %% [markdown]
# ### **2.4.5 Ubicación geográfica de la empresa**

# %% [markdown]
# #### **Comprobación de normalidad de los datos**

# %%
from scipy.stats import shapiro

# Ejecutar la prueba de Shapiro-Wilk por grupo de 'Sector'
resultados_shapiro = []

for group in df_analysis_multivariate_final['Geographic reach location'].unique():
    datos_grupo = df_analysis_multivariate_final[df_analysis_multivariate_final['Geographic reach location'] == group]['Latent_transformation']
    
    # Evitar aplicar la prueba si hay menos de 3 observaciones (Shapiro requiere al menos 3)
    if len(datos_grupo) < 3:
        resultados_shapiro.append({
            "Geographic reach location": group,
            "N": len(datos_grupo),
            "Estadístico": None,
            "p-valor": None,
            "Normalidad": "No aplica (<3 observaciones)"
        })
        continue
    
    stat, p = shapiro(datos_grupo)
    normalidad = "Normal (no rechaza H0)" if p >= 0.05 else "No es normal (rechaza H0)"
    resultados_shapiro.append({
        "Geographic reach location": group,
        "N": len(datos_grupo),
        "Estadístico": stat,
        "p-valor": p,
        "Normalidad": normalidad
    })

import pandas as pd
df_shapiro = pd.DataFrame(resultados_shapiro)
df_shapiro

# %% [markdown]
# El número de empresas regional es apenas 2, por lo que no se puede comprobar normalidad en ese grupo. Por tanto, se excluye del análisis.

# %%
# Quitar registros con location regional
df_analysis_multivariate_final_location=df_analysis_multivariate_final[df_analysis_multivariate_final['Geographic reach location'] != 'Regional']

# %%
#### **Comprobación de homogeneidad de varianzas**

# Agrupar los datos de 'Indice_Sensing' por ubicación geográfica
grupos = df_analysis_multivariate_final_location.groupby('Geographic reach location')['Latent_transformation'].apply(list)

# Aplicar la prueba de Levene
stat_levene, p_levene = levene(*grupos)

# Mostrar resultados
stat_levene, p_levene

# Imprimir el resultado
print("📊 Resultado de la prueba de Levene (homogeneidad de varianzas)")
print("---------------------------------------------------------------")
print(f"Estadístico de Levene: {stat_levene:.4f}")
print(f"Valor p: {p_levene:.4f}")

if p_levene < 0.05:
    print("→ Se rechaza la hipótesis nula: hay evidencia de que las varianzas no son iguales.")
else:
    print("→ No se rechaza la hipótesis nula: no hay evidencia de que las varianzas sean diferentes.")

# %% [markdown]
# Se comprueba homogeneidad de varianzas para aplicar ANOVA.

# %%
# 1. Classical ANOVA
groups = df_analysis_multivariate_final.groupby('Geographic reach location')['Latent_transformation'].apply(list)
f_stat, p_value = f_oneway(*groups)

print("\nClassical ANOVA results:")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# 2. Check if significant
if p_value < 0.05:
    print("\nANOVA is significant (p < 0.05). Applying Tukey HSD test...")

    # 3. Tukey HSD post-hoc test
    tukey = pairwise_tukeyhsd(endog=df_analysis_multivariate_final['Latent_transformation'],
                              groups=df_analysis_multivariate_final['Geographic reach location'],
                              alpha=0.05)
    tukey_summary = pd.DataFrame(data=tukey.summary().data[1:], columns=tukey.summary().data[0])
    tukey_summary['Interpretation'] = tukey_summary['p-adj'].apply(lambda x: 'Different' if x < 0.05 else 'Equal')

    # 4. Compute medians by group and sort
    medians = df_analysis_multivariate_final.groupby('Geographic reach location')['Latent_transformation'].median().reset_index()
    category_order = medians.sort_values('Latent_transformation', ascending=False)['Geographic reach location'].tolist()

    # 5. Create figure (boxplot + table)
    fig, ax = plt.subplots(2, 1, figsize=(8, 8), gridspec_kw={'height_ratios': [3, 1]})

    sns.boxplot(x='Geographic reach location', y='Latent_transformation', data=df_analysis_multivariate_final,
                ax=ax[0], palette="Set2", order=category_order)
    ax[0].set_title("Sensing by Geographic reach location")
    ax[0].set_xlabel("Geographic reach location")
    ax[0].set_ylabel("Latent Variable (Sensing)")

    # Annotate medians
    for i, row in medians.iterrows():
        idx = category_order.index(row['Geographic reach location'])
        offset = 0.05
        ax[0].text(idx, row['Latent_transformation'] + offset, 
                   f"{row['Latent_transformation']:.2f}", 
                   ha='center', va='bottom', fontweight='bold', color='black',
                   bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.05', linewidth=0.3))

    # 6. Add table below the plot
    table = tukey_summary[['group1', 'group2', 'Interpretation']]
    ax[1].axis('off')
    table_text = table.values.tolist()
    column_labels = ['Group 1', 'Group 2', 'Comparison']
    ax[1].table(cellText=table_text, colLabels=column_labels, loc='center', cellLoc='center')

    plt.tight_layout()
    plt.show()

else:
    print("\nANOVA is not significant (p ≥ 0.05). Tukey HSD test and plot will not be generated.")

# %% [markdown]
# No hay evidencia estadísticamente significativa de que las medias del Indice_Transformation difieran entre las ubicaciones geográficas (National, Local, International).

# %%
fig_boxplot = plt.figure(figsize=(10,5)) 
ax = fig_boxplot.add_axes([0,0,1,1])

resumen=df_analysis_multivariate_final_location.groupby(by=["Geographic reach location"])["Latent_transformation"].describe()

ax=sns.boxplot(x=df_analysis_multivariate_final_location["Geographic reach location"], y=df_analysis_multivariate_final_location["Latent_transformation"],order=resumen.sort_values(by='50%', ascending=False).index)
plt.ylabel('')   
plt.xlabel('')           
plt.show()

# %% [markdown]
# ### **2.4.6 Edad de la empresa**

# %%
# Pearson correlation coefficient and p-value calculation
r, p_value = pearsonr(df_analysis_multivariate_final['Latent_transformation'], df_analysis_multivariate_final['Age of company'])

# Results
print(f"Pearson correlation coefficient: r = {r:.4f}")
print(f"p-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("There is significant evidence of a linear correlation between 'Latent_transformation' and 'Age of company'.")
else:
    print("No significant evidence of a linear correlation was found between 'Latent_transformation' and 'Age of company'.")

# Visualization
plt.figure(figsize=(8, 6))
sns.regplot(data=df_analysis_multivariate_final, x='Age of company', y='Latent_transformation', ci=95, line_kws={'color': 'red'})
plt.title(f"Correlation between Latent Variable (Transformation) and Age of Company\nr = {r:.2f}, p = {p_value:.4f}")
plt.xlabel("Age of company")
plt.ylabel("Latent variable (Transformation)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Nivel de significancia
alpha = 0.05

# Spearman
rho_spearman, p_spearman = spearmanr(df_analysis_multivariate_final['Latent_transformation'], df_analysis_multivariate_final['Age of company'])
print("=== Correlación de Spearman ===")
print(f"Coeficiente rho: {rho_spearman:.4f}")
print(f"Valor p: {p_spearman:.4f}")
if p_spearman < alpha:
    print("→ Existe una relación monótona significativa entre las variables (se rechaza H₀).")
else:
    print("→ No existe una relación monótona significativa entre las variables (no se rechaza H₀).")

print("\n")

# Kendall
tau_kendall, p_kendall = kendalltau(df_analysis_multivariate_final['Latent_transformation'], df_analysis_multivariate_final['Age of company'])
print("=== Correlación de Kendall ===")
print(f"Coeficiente tau: {tau_kendall:.4f}")
print(f"Valor p: {p_kendall:.4f}")
if p_kendall < alpha:
    print("→ Existe una relación significativa según Kendall (se rechaza H₀).")
else:
    print("→ No existe una relación significativa según Kendall (no se rechaza H₀).")

# %% [markdown]
# No se considera necesario avanzar hacia la aplicaciòn de una regresión lineal simple, ya que la prueba de correlación de Pearson ya ha indicado que no hay evidencia de una relación lineal significativa entre las variables 'Latent_Transformation' y 'Age of company'.

# %% [markdown]
# ### **2.2.8 R&D Expenditure**

# %%
# Pearson correlation coefficient and p-value calculation
r, p_value = pearsonr(df_analysis_multivariate_final['Latent_transformation'], df_analysis_multivariate_final['R&D expenditure'])

# Results
print(f"Pearson correlation coefficient: r = {r:.4f}")
print(f"p-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("There is significant evidence of a linear correlation between 'Latent_transformation' and 'R&D expenditure'.")
else:
    print("No significant evidence of a linear correlation was found between 'Latent_transformation' and 'R&D expenditure'.")

# Visualization
plt.figure(figsize=(8, 6))
sns.regplot(data=df_analysis_multivariate_final, x='R&D expenditure', y='Latent_transformation', ci=95, line_kws={'color': 'red'})
plt.title(f"Correlation between Latent Variable (Transformation) and R&D expenditure\nr = {r:.2f}, p = {p_value:.4f}")
plt.xlabel("R&D expenditure")
plt.ylabel("Latent variable (Transformation)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Nivel de significancia
alpha = 0.05

# Spearman
rho_spearman, p_spearman = spearmanr(df_analysis_multivariate_final['Latent_transformation'], df_analysis_multivariate_final['R&D expenditure'])
print("=== Correlación de Spearman ===")
print(f"Coeficiente rho: {rho_spearman:.4f}")
print(f"Valor p: {p_spearman:.4f}")
if p_spearman < alpha:
    print("→ Existe una relación monótona significativa entre las variables (se rechaza H₀).")
else:
    print("→ No existe una relación monótona significativa entre las variables (no se rechaza H₀).")

print("\n")

# Kendall
tau_kendall, p_kendall = kendalltau(df_analysis_multivariate_final['Latent_transformation'], df_analysis_multivariate_final['R&D expenditure'])
print("=== Correlación de Kendall ===")
print(f"Coeficiente tau: {tau_kendall:.4f}")
print(f"Valor p: {p_kendall:.4f}")
if p_kendall < alpha:
    print("→ Existe una relación significativa según Kendall (se rechaza H₀).")
else:
    print("→ No existe una relación significativa según Kendall (no se rechaza H₀).")

# %% [markdown]
# ### **2.2.9 Number of patents innovations**

# %%
df_analysis_multivariate_final

# %%
# Specific variables
df_plot = df_analysis_multivariate_final.copy()
y_var = "Latent_transformation"
x_var = "Number of patents innovations"

# Fit linear regression model
X = df_plot[[x_var]]  # design matrix (2D)
y = df_plot[y_var]
model = LinearRegression().fit(X, y)

# Predict values and compute R²
y_pred = model.predict(X)
r2 = r2_score(y, y_pred)

# Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x=x_var, y=y_var, data=df_plot, color='darkgreen', s=60)
sns.lineplot(x=df_plot[x_var], y=y_pred, color='red', linewidth=2, label='Linear regression')

# Customize labels and title
plt.title("Relationship between Latent Variable (Transformation) and Number of patent innovations", fontsize=14)
plt.xlabel("Latent Variable (Transformation)")
plt.ylabel("Number of patent innovations")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_promedio_empresa_corr=df_analysis_multivariate_final.copy()

# Cammbio de nombre de Indice_Transormation
df_promedio_empresa_corr.rename(columns={'Latent_transformation': 'Latent variable (Transormation)'}, inplace=True)

# Elegir las columnas que se desean analizar
df_promedio_empresa_corr = df_promedio_empresa_corr[["Latent variable (Transormation)","Number of patents innovations"]]

categorical_features=identify_nominal_columns(df_promedio_empresa_corr)
continuous_features=identify_numeric_columns(df_promedio_empresa_corr)

# %%
from dython.nominal import associations
target_correlation= associations(df_promedio_empresa_corr, display_rows=["Latent variable (Transormation)"], filename= 'target_correlation.png', figsize=(20,5))

# %%
from scipy.stats import spearmanr

# Supongamos que tienes dos variables en un DataFrame
x = df_analysis_multivariate_final['Latent_transformation']
y = df_analysis_multivariate_final['R&D expenditure']

# Calcular la correlación de Spearman
coef, p_value = spearmanr(x, y)

print(f"Coeficiente de Spearman: {coef:.4f}")
print(f"Valor p: {p_value:.4f}")

# Interpretación
if p_value < 0.05:
    print("✔️ La correlación es estadísticamente significativa.")
else:
    print("❌ No hay evidencia de una correlación significativa.")

# %%
from scipy.stats import kendalltau

# Supón que tienes tus dos variables en un DataFrame
x = df_analysis_multivariate_final['Latent_transformation']
y = df_analysis_multivariate_final['R&D expenditure']

# Calcular la correlación de Kendall
coef, p_value = kendalltau(x, y)

print(f"Coeficiente de Kendall τ: {coef:.4f}")
print(f"Valor p: {p_value:.4f}")

# Interpretación
if p_value < 0.05:
    print("✔️ La correlación es estadísticamente significativa.")
else:
    print("❌ No hay evidencia de una correlación significativa.")

# %%
df_promedio_empresa_reg_lineal = df_analysis_multivariate_final[["Latent_transformation","Number of patents innovations"]]

x=df_promedio_empresa_reg_lineal.drop(["Latent_transformation"], axis=1)
y=df_promedio_empresa_reg_lineal["Latent_transformation"]
X = sm.add_constant(x) 
model = sm.OLS(y,X)
result=model.fit()
result.summary()

# %% [markdown]
# **I) Linealidad**

# %%
# Extrae las columnas Y y X del DataFrame
Y = df_analysis_multivariate_final['Number of patents innovations']
X = df_analysis_multivariate_final['Latent_transformation']

# %%
# Calcula el coeficiente de correlación de Pearson y el valor p
correlation_coefficient, p_value = stats.pearsonr(Y, X)

# nivel de significancia (alpha)
alpha = 0.05

# Comparar el valor p con el nivel de significancia
if p_value < alpha:
    print("Hay evidencia de una relación lineal significativa (p < alpha)")
else:
    print("No hay evidencia de una relación lineal significativa (p >= alpha)")

print(f"Coeficiente de correlación de Pearson: {correlation_coefficient}")
